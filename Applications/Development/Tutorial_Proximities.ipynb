# %%
# %load_ext autoreload
# %autoreload 2

# %%
import neurd
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
from neurd.vdi_microns import volume_data_interface as vdi
vdi.set_parameters_for_directory_modules()

# %%
from os import sys
sys.path.append("/neurd_packages/meshAfterParty/meshAfterParty/")

# %%
from dataInterfaceMinnie65 import data_interface as hdju
# Out:
# Connecting celiib@at-database.ad.bcm.edu:3306
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.utils:WARNING:Imported datajoint_plus version, 0.1.0 does not match the latest version on Github, 0.1.7.
# 09-21-2023 07:40:51 PM UTC - datajoint.settings:INFO:Setting enable_python_native_blobs to True
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:51 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:40:52 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# ...
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:ERROR:module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 09-21-2023 07:41:05 PM UTC - datajoint_plus.table:INFO:failure interacting with ~tables
# 09-21-2023 07:41:05 PM UTC - google.auth._default:WARNING:No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable
# Using default Google credentials. There is no ~/.cloudvolume/secrets/google-secret.json set.

# %%
vdi.set_parameters_for_directory_modules()

segment_id_pre = 864691135567721964
directory = "../Auto_Proof_Pipeline/Single_Soma_Inh/"

neuron_obj_pre = vdi.load_neuron_obj_auto_proof(
    segment_id_pre,
    directory = directory,
    meshes_directory = directory,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 6
#       3 segment_id_pre = 864691135567721964
#       4 directory = "../Auto_Proof_Pipeline/Single_Soma_Inh/"
# ----> 6 neuron_obj_pre = vdi.load_neuron_obj_auto_proof(
#       7     segment_id_pre,
#       8     directory = directory,
#       9     meshes_directory = directory,
#      10 )
#      12 vdi.set_parameters_for_directory_modules()
#      14 segment_id_post = 864691134917511946
#
# File /neurd_packages/NEURD/neurd/vdi_default.py:390, in DataInterfaceDefault.load_neuron_obj_auto_proof(self, segment_id, mesh_decimated, directory, **kwargs)
#     387 if "suffix" not in kwargs:
#     388     kwargs["suffix"] = self.neuron_obj_auto_proof_suffix
# --> 390 return self.load_neuron_obj(
#     391     segment_id,
#     392     mesh_decimated = mesh_decimated,
#     393     directory=directory,
#     394     **kwargs
#     395 )
#
# File /neurd_packages/NEURD/neurd/vdi_default.py:294, in DataInterfaceDefault.load_neuron_obj(self, segment_id, mesh_decimated, meshes_directory, filepath, directory, filename, suffix, verbose, **kwargs)
#     281 def load_neuron_obj(
#     282     self,
#     283     segment_id,
#    (...)
#     290     verbose = False,
#     291     **kwargs):
#     293     if mesh_decimated is None:
# --> 294         mesh_decimated = self.fetch_segment_id_mesh(
#     295             segment_id,
#     296             meshes_directory = meshes_directory,)
#     298     if filepath is None:
#     299         if directory is None:
#
# File /neurd_packages/NEURD/neurd/vdi_default.py:164, in DataInterfaceDefault.fetch_segment_id_mesh(self, segment_id, meshes_directory, plot, ext)
#     159     meshes_directory = self.meshes_directory
#     161 mesh_filepath = Path(meshes_directory) / Path(
#     162     f"{segment_id}.{ext}")
# --> 164 mesh = tu.load_mesh_no_processing(mesh_filepath)
#     166 if plot:
#     167     nviz.plot_objects(mesh)
#
# File /neurd_packages/mesh_tools/mesh_tools/trimesh_utils.py:43, in load_mesh_no_processing(current_mesh_file)
#      41 if current_mesh_file[-4:] != ".off":
#      42     current_mesh_file += ".off"
# ---> 43 return trimesh.load_mesh(current_mesh_file,process=False)
#
# File /usr/local/lib/python3.8/dist-packages/trimesh/exchange/load.py:215, in load_mesh(file_obj, file_type, resolver, **kwargs)
#     213 loader = mesh_loaders[file_type]
#     214 tic = now()
# --> 215 results = loader(file_obj,
#     216                  file_type=file_type,
#     217                  resolver=resolver,
#     218                  **kwargs)
#     219 if not isinstance(results, list):
#     220     results = [results]
#
# File /usr/local/lib/python3.8/dist-packages/trimesh/exchange/off.py:43, in load_off(file_obj, **kwargs)
#      40 header = np.array(splits[0].split(), dtype=np.int64)
#      41 vertex_count, face_count = header[:2]
# ---> 43 vertices = np.array([
#      44     i.split()[:3] for i in
#      45     splits[1: vertex_count + 1]],
#      46     dtype=np.float64)
#      48 # will fail if incorrect number of vertices loaded
#      49 vertices = vertices.reshape((vertex_count, 3))
#
# File /usr/local/lib/python3.8/dist-packages/trimesh/exchange/off.py:44, in <listcomp>(.0)
#      40 header = np.array(splits[0].split(), dtype=np.int64)
#      41 vertex_count, face_count = header[:2]
#      43 vertices = np.array([
# ---> 44     i.split()[:3] for i in
#      45     splits[1: vertex_count + 1]],
#      46     dtype=np.float64)
#      48 # will fail if incorrect number of vertices loaded
#      49 vertices = vertices.reshape((vertex_count, 3))
#
# KeyboardInterrupt:

# %%
segment_id_post = 864691134917511946
directory = "../Auto_Proof_Pipeline/Single_Soma_Exc/"

neuron_obj_post = vdi.load_neuron_obj_auto_proof(
    segment_id_post,
    directory = directory,
    meshes_directory = directory,
)
# Out:
# Decompressing Neuron in minimal output mode...please wait

# %%
from neurd import synapse_utils as syu
# Out:
# [99518765,
#  91656568,
#  91657053,
#  89712452,
#  91656613,
#  91656665,
#  91656730,
#  92315464,
#  97851203,
#  91418562,
#  92314562,
#  91418203,
#  89711717,
#  91418663,
#  99708361,
#  99708562,
#  91418503,
#  99708790,
#  89711743,
#  99708061,
#  99708631,
#  91418492,
#  92104066,
#  92315320,
#  91418656,
#  91656827,
#  99519258,
#  92314921,
#  97851302,
#  99708369,
#  92315451,
#  89711846,
#  92315074,
#  99708292,
#  91418461,
#  91418670,
#  91418727,
#  89711783,
#  91418567,
#  91418719,
#  91418681,
#  99708143,
#  91656241,
#  91656295,
#  91656959,
#  99519183,
#  92104229,
#  89711811,
#  89711944,
#  99518737,
#  97631363,
#  99708065,
#  99708281,
#  75240600,
#  48489532,
#  48494236,
#  48489518,
#  510786559,
#  510786058,
#  510784522,
#  48492593,
#  510784537,
#  66631279,
#  48494402,
#  75240606,
#  61522894,
#  66634629,
#  510787435,
#  510786744,
#  510785809,
#  48489376,
#  510785011,
#  75240290,
#  48490285,
#  48491274,
#  510786494,
#  75239408,
#  510786663,
#  48489373,
#  510785946,
#  61524647,
#  61524592,
#  66634092,
#  510784725,
#  48490267,
#  66633019,
#  66633870,
#  66633302,
#  66631095,
#  66634406,
#  66719955,
#  510787996,
#  66632818,
#  75240667,
#  66632306,
#  61522151,
#  510788329,
#  61522229,
#  510785361,
#  61524312,
#  61521974,
#  61523707,
#  61523808,
#  75239285,
#  73995652,
#  67548375,
#  83896350,
#  83896611,
#  67550767,
#  73997054,
#  67551347,
#  73996745,
#  67549191,
#  67549955,
#  67550895,
#  83896424,
#  83895117,
#  83895295,
#  73997944,
#  73997586,
#  83896427,
#  73998478,
#  73998896,
#  67550303,
#  83896637,
#  67549793,
#  61171675,
#  92314419,
#  92314384,
#  92314282,
#  92314426,
#  92314320,
#  92314277,
#  83941380,
#  86722425,
#  92107006,
#  92105909,
#  88447393,
#  92105861,
#  92107949,
#  92106715,
#  88446670,
#  86722421,
#  92107233,
#  92314268,
#  90001775,
#  88847183,
#  91863925,
#  88847386,
#  90001721,
#  88847770,
#  90001802,
#  88671903,
#  88847807,
#  88847949,
#  90001610,
#  78044675,
#  88847173,
#  88847280,
#  90001951,
#  88847371,
#  88848583,
#  88671383,
#  88671448,
#  90001790,
#  88847848,
#  91864194,
#  88671669,
#  88847945,
#  77809952,
#  91864283,
#  91863856,
#  88846629,
#  88846600,
#  91863670,
#  77809849,
#  90001633,
#  90002121,
#  88671243,
#  88671755,
#  92314208,
#  91864257,
#  91864230,
#  91863964,
#  91864069,
#  91864343,
#  91864528,
#  91864147,
#  91864043,
#  92314252,
#  91864276,
#  112225436,
#  105780407,
#  105780632,
#  112387738,
#  99589892,
#  105782863,
#  97283144,
#  112101302,
#  112099904,
#  103391365,
#  103391676,
#  88673675,
#  119663720,
#  99590147,
#  99589000,
#  91865362,
#  99590197,
#  112101657,
#  105782538,
#  105781157,
#  119610596,
#  105780335,
#  105782768,
#  105781633,
#  105782200,
#  99590529,
#  99589081,
#  99589179,
#  112225028,
#  112225104,
#  105780849,
#  103391486,
#  91864710,
#  105781388,
#  105781165,
#  91865036,
#  91865561,
#  112099417,
#  119611090,
#  105782164,
#  119118419,
#  99590813,
#  97598168,
#  119611302,
#  119611647,
#  112101790,
#  112225062,
#  112225957,
#  91864696,
#  99590995,
#  112224757,
#  103391368,
#  110562558,
#  112102196,
#  112224772,
#  103391723,
#  119574274,
#  99590120,
#  97283421,
#  119574435,
#  99590084,
#  91865093,
#  91865405,
#  105782480,
#  110562826,
#  97178219,
#  91965188,
#  97178967,
#  97178615,
#  91964889,
#  97178044,
#  97178080,
#  91864366,
#  91965729,
#  91965559,
#  97598382,
#  97179057,
#  91965418,
#  97178468,
#  97178177,
#  97178798,
#  91965182,
#  91965207,
#  89711820,
#  89712654,
#  89712334,
#  89711663,
#  89541416,
#  89712393,
#  92314650,
#  89948742,
#  100816967,
#  100817262,
#  89948994,
#  97267653,
#  97268141,
#  91608027,
#  97356706,
#  97356653,
#  97356441,
#  90121311,
#  100817100,
#  96968100,
#  100817179,
#  96431280,
#  93735145,
#  92137122,
#  91607640,
#  91607756,
#  92137157,
#  89948948,
#  90121921,
#  90122115,
#  97266157,
#  100817436,
#  97336562,
#  89948460,
#  100817922,
#  100817192,
#  97266152,
#  100817030,
#  ...]

# %%
neuron_obj_post.split_index = 1

# %%
vdi.set_parameters_for_directory_modules()

# %%
segment_id_post = 864691134917511946
segment_id_pre = 864691135567721964

hdju.pre_post_synapse_ids_coords_from_connectome(
    segment_id_pre,
    segment_id_post,
    
)
# Out:
# (array([89885603, 105007182], dtype=object),
#  array([[ 545224.,  766824.,  925200.],
#         [ 585832.,  726176., 1026000.]]))

# %%
neuron_obj_pre.pipeline_products.cell_type_ax_dendr.split_index = 0
neuron_obj_pre

# %%
vdi.set_parameters_for_directory_modules()
vdi.pre_post_synapse_ids_coords_from_connectome(
    neuron_obj_pre,
    neuron_obj_post,
)
# Out:
# (array([ 89885603, 105007182]),
#  array([[ 545224.,  766824.,  925200.],
#         [ 585832.,  726176., 1026000.]]))

# %%
vdi.set_parameters_for_directory_modules()

synapse_pre_df = vdi.segment_id_to_synapse_table_optimized_proofread(
    neuron_obj_pre,
    synapse_type="presyn"
)
synapse_pre_df
# Out:
#           primary_seg_id    secondary_seg_id  synapse_id prepost  synapse_x  \
# 0     864691135567721964  864691132317921855    90129520  presyn     137978
# 1     864691135567721964  864691132540381714    66225125  presyn     123808
# 2     864691135567721964  864691132564601546    90037862  presyn     137454
# 3     864691135567721964  864691132612900895    72177638  presyn     128808
# 4     864691135567721964  864691132702913954    54422709  presyn     115153
# ...                  ...                 ...         ...     ...        ...
# 1119  864691135567721964  864691137197079873   109752846  presyn     147963
# 1120  864691135567721964  864691137197144897    82142120  presyn     120725
# 1121  864691135567721964  864691137197144897    82142719  presyn     121331
# 1122  864691135567721964  864691137197151297   104203877  presyn     142890
# 1123  864691135567721964  864691137197151297   104205943  presyn     144197
#
#       synapse_y  synapse_z  synapse_size  synapse_x_nm  synapse_y_nm  ...  \
# 0        181084      22914          1592        551912        724336  ...
# 1        178640      23539          2188        495232        714560  ...
# 2        181248      23026          1348        549816        724992  ...
# 3        180124      23007          2024        515232        720496  ...
# 4        171021      23302           236        460612        684084  ...
# ...         ...        ...           ...           ...           ...  ...
# 1119     161964      24664          1008        591852        647856  ...
# 1120     188896      24233           276        482900        755584  ...
# 1121     188683      24233          1504        485324        754732  ...
# 1122     172428      24107          4528        571560        689712  ...
# 1123     172298      24104          4228        576788        689192  ...
#
#                                 closest_face_coordinate  \
# 0      [551932.2000000001, 724332.7999999999, 916567.6]
# 1     [495207.9666666666, 714595.1666666666, 941583....
# 2      [549773.0333333333, 724936.0, 921058.7666666666]
# 3      [515279.3333333333, 720506.4666666667, 920249.0]
# 4     [460611.89999999997, 684022.2333333334, 932042...
# ...                                                 ...
# 1119  [591868.7333333333, 647879.1666666666, 986585....
# 1120  [482907.93333333335, 755568.8666666667, 969367.5]
# 1121  [485341.06666666665, 754662.6333333333, 969263...
# 1122  [571531.4666666667, 689726.6333333334, 964342....
# 1123            [576802.4, 689195.6, 964155.6999999998]
#
#       skeletal_distance_to_soma  soma_distance_euclidean spine_bouton  \
# 0                 192490.533475                     None   non_bouton
# 1                 210919.815397                     None   non_bouton
# 2                 186977.065348                     None   non_bouton
# 3                 211657.586174                     None       bouton
# 4                 250812.469353                     None   non_bouton
# ...                         ...                      ...          ...
# 1119              243009.397976                     None   non_bouton
# 1120              257535.292840                     None   non_bouton
# 1121              254636.481741                     None   non_bouton
# 1122              181157.445483                     None   non_bouton
# 1123              187197.155764                     None   non_bouton
#
#       compartment  limb_idx branch_idx     label  compartment_coarse  \
# 0            axon       0.0      117.0  no_label                axon
# 1            axon       0.0       53.0  no_label                axon
# 2            axon       0.0      117.0  no_label                axon
# 3            axon       0.0       82.0  no_label                axon
# 4            axon       0.0        7.0  no_label                axon
# ...           ...       ...        ...       ...                 ...
# 1119         axon       0.0      235.0  no_label                axon
# 1120         axon       0.0       20.0  no_label                axon
# 1121         axon       0.0       29.0  no_label                axon
# 1122         axon       0.0      158.0  no_label                axon
# 1123         axon       0.0      158.0  no_label                axon
#
#       compartment_fine
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
# ...                ...
# 1119              None
# 1120              None
# 1121              None
# 1122              None
# 1123              None
#
# [1124 rows x 31 columns]

# %%
neuron_obj_pre.neuron_graph_after_proof

# %%
from neurd import neuron
from neuron_morphology_tools import neuron_nx_utils as nxu

# %% [markdown]
# # Practicing the method overloading

# %%
hdju.segment_id_to_synapse_table_optimized_connectome(segment_id_pre)

# %%
hdju.segment_id_to_synapse_table_optimized(segment_id_pre)

# %%
curr_df = hdju.df_from_table(hdju.segment_id_to_synapse_table_optimized_proofread(segment_id_pre))
list(curr_df.columns)

# %%
import pandas as pd
from datasci_tools import pandas_utils as pu

from neurd.vdi_microns import volume_data_interface as vdi
vdi.set_parameters_for_directory_modules()

from neurd import apical_utils as apu

proof_df = vdi.segment_id_to_synapse_table_optimized_proofread(
    neuron_obj_pre,
    #synapse_type = 'presyn'
)
proof_df

# %%
proof_df.synapse_id.numpy()

# %%
syu.synaneuron_obj_pre.synapses_valid

# %%
vdi.segment_id_to_synapse_table_optimized(
    neuron_obj_pre,
    synapse_type = 'presyn'
)

# %%
from neurd import synapse_utils as syu
from datasci_tools import pandas_utils as pu
import numpy as np


from neurd.vdi_microns import volume_data_interface as vdi
vdi.set_parameters_for_directory_modules()

neuron_obj_pre.pipeline_products.cell_type_ax_dendr.synapse_filepath = str(Path(
    "../Auto_Proof_Pipeline/Single_Soma_Inh/864691135567721964_synapses.csv"
).absolute())

return_df = vdi.segment_id_to_synapse_table_optimized(
    neuron_obj_pre,
    #synapse_filepath = "../Auto_Proof_Pipeline/Single_Soma_Inh/864691135567721964_synapses.csv"
)

return_df

# %%
from pathlib import Path

# %%
neuron_obj_pre.synapse_filepath

# %%
mesh_dir = "../Auto_Proof_Pipeline/Single_Soma_Inh/"

vdi.neuron_obj_auto_proof_directory = mesh_dir
vdi.neuron_obj_directory = mesh_dir
vdi.meshes_directory = mesh_dir

# %% [markdown]
# # Loading the annotated neurons

# %%
segment_id_post = 864691134917511946
segment_id_pre = 864691135567721964

# %%
vdi.set_parameters_for_directory_modules()

neuron_obj_pre = vdi.load_neuron_obj_auto_proof(
    segment_id_pre,
    directory = "../Auto_Proof_Pipeline/Single_Soma_Inh/"
)

# %%
vdi.load_neuron_obj_auto_proof?

# %%
from neurd import neuron_visualizations as nviz

nviz.plot_compartments(neuron_obj_pre)

# %%
nviz.plot_compartments(neuron_obj_post)

# %% [markdown]
# # Calculating the proximities

# %%
presyn_prox_data = pxu.presyn_proximity_data(
    segment_id = segment_id,
    split_index = split_index,
    plot = False,
    verbose = False
)

# %%
verbose = True
from neurd import proximity_utils as pxu

# %%
prox_data = pxu.proximity_pre_post(
    segment_id_pre = neuron_obj_pre,
    segment_id_post = neuron_obj_post,
    plot_proximities = False,
    verbose = verbose,
    return_df = False
)

# %%
def presyn_proximity_data(
    segment_id,
    split_index,
    plot = False,
    verbose = False,
    ):
    """
    Purpose: Get the presyn proximity information
    before pairwise proximities are computed
    """
    st = time.time()
    #1) computes the synapse presyn side of the connectome
    synapse_pre_df = vdi.segment_id_to_synapse_table_optimized_connectome(
        segment_id=segment_id,
        split_index=split_index,
        syn_type = "presyn",
        coordinates_nm = True,
        return_df=True)
    
    synapse_pre_raw_df = vdi.segment_id_to_synapse_table_optimized(
        segment_id=segment_id,
        synapse_type = "presyn",
        coordinates_nm = True,
        return_df=True)
    
    synapse_pre_raw_coords = pxu.synapse_coordinates_from_df(synapse_pre_raw_df)
    
    synapse_pre_proof_df = vdi.segment_id_to_synapse_table_optimized_proofread(
        segment_id=segment_id,
        synapse_type = "presyn",
        coordinates_nm = True,
        return_df=True)
    
    synapse_pre_proof_coords = pxu.synapse_coordinates_from_df(synapse_pre_proof_df)


    #2) Gets the mesh for later plotting
    if plot:
        mesh = vdi.fetch_proofread_mesh(
            segment_id,
            split_index)
    else:
        mesh = None

    #3) Gets some coordinate for later euclidean distance calculation
    presyn_soma_coord = vdi.soma_nm_coordinate(
        segment_id,
        split_index)

    #4) Fetches neuron object  for calculations
    G_presyn = vdi.graph_obj_from_proof_stage(segment_id,split_index)


    #5) Calculating all of the width,compartments and skeletons
    (presyn_skeleton_array,
    presyn_width_array,
    presyn_comp_array) = nxu.skeleton_width_compartment_arrays_from_G(
        G_presyn,
        compartments=["axon"],
    )

    #5) Fetches the skeleton and starting coordinate of axon 
    #   to be used later for skeletal distance to soma

    presyn_starting_coordinate = nxu.most_upstream_node_on_axon_limb(
        G_presyn,
        return_endpoint_upstream = True
    )

    if plot:
        print(f"Plotting: Presyn axon skeleton")
    (pre_sk_vert,
    pre_sk_edges)= nxu.axon_skeleton(
        G = G_presyn,
        include_path_to_soma = True,
        plot=plot,
        mesh = mesh,

    )
    
    #G_presyn_sk = sk.convert_skeleton_to_graph(pre_sk_vert[pre_sk_edges])
    G_presyn_sk = xu.graph_from_non_unique_vertices_edges(pre_sk_vert,pre_sk_edges)

    if plot:
        print(f"Plotting: Presyn skeleton and starting coordinate")
        nviz.plot_objects(
            scatters=[pre_sk_vert,presyn_starting_coordinate],
            scatters_colors=["red","blue"],
            scatter_size=[0.2,2]
        )
        
    if verbose:
        print(f"Total time for presyn proximity data = {time.time() - st}")

    return dict(
        # for the synapses to be checked if in vicinity
        synapse_pre_df = synapse_pre_df,

        # for attributes for computing proximities
        presyn_skeleton_array=presyn_skeleton_array,
        presyn_width_array=presyn_width_array,
        presyn_comp_array=presyn_comp_array,


        # for skeletal walk distance
        presyn_starting_coordinate=presyn_starting_coordinate,
        pre_sk_vert=pre_sk_vert,
        pre_sk_edges=pre_sk_edges,
        G_presyn_sk=G_presyn_sk,

        # for computing euclidean distance
        presyn_soma_coord =presyn_soma_coord,
        
        # for more features to compute close to
        synapse_pre_raw_coords=synapse_pre_raw_coords,
        synapse_pre_proof_coords=synapse_pre_proof_coords,
        
        #for ploting 
        mesh = mesh
    )

# %%
def postsyn_proximity_data(
    segment_id,
    split_index,
    plot = False,
    verbose = False,
    check_starting_coord_match_skeleton = False,
    
    ):

    """
    Purpose: Get the postsyn proximity information
    before pairwise proximities are computed
    """
    segment_id_target = segment_id
    split_index_target = split_index

    st = time.time()
    #2) Gets the mesh for later plotting
    if plot:
        mesh_post = vdi.fetch_proofread_mesh(
            segment_id_target,
            split_index_target
        )
    else:
        mesh_post = None

    #3) Gets some coordinate for later euclidean distance calculation
    postsyn_soma_coord = vdi.soma_nm_coordinate(
        segment_id_target,
        split_index=split_index_target)

    #4) Fetches neuron object  for calculations
    G_postsyn = vdi.graph_obj_from_proof_stage(segment_id_target,split_index_target)

    #4) Calculating all the skeleton arrays, widths, compartments
    (postsyn_skeleton_array,
    postsyn_width_array,
    postsyn_comp_array) = nxu.skeleton_width_compartment_arrays_from_G(
        G_postsyn,
        plot=False
    )

    postsyn_soma_mesh = vdi.fetch_soma_mesh(
        segment_id_target,
        split_index_target,
        plot_soma = False)

    soma_array = np.array(postsyn_soma_mesh.vertices)
    postsyn_skeleton_array = np.vstack([postsyn_skeleton_array,postsyn_soma_mesh.vertices])
    postsyn_width_array = np.hstack([postsyn_width_array,np.repeat([0],len(soma_array))])
    postsyn_comp_array = np.hstack([postsyn_comp_array,np.repeat(["soma"],len(soma_array))])

    if plot:
        print(f"Plotting: postsyn skeleton array")
        ipvu.plot_mesh_with_scatter(
            mesh_post,
            scatter=postsyn_skeleton_array,
        )

    #5) Fetches the skeleton and starting coordinate of axon 
    #   to be used later for skeletal distance to soma

    if plot:
        print(f"Plotting: postsyn skeleton")
    (post_sk_vert,
    post_sk_edges)= nxu.skeleton(
        G = G_postsyn,
        plot=plot,
        mesh = mesh_post,
        )  

    postsyn_starting_coords= nxu.starting_coordinates_all_limbs(
                G_postsyn,
                verbose = False)


    if check_starting_coord_match_skeleton:
        for k in postsyn_starting_coords.reshape(-1,3):
            min_dist = nu.closest_dist_between_coordinates(
                post_sk_vert.reshape(-1,3),
                k.reshape(-1,3),
                return_min=True
            )

            if min_dist > 0:
                raise Exception("")

    #6) Postsyn and spine data
    synapse_post_df = vdi.segment_id_to_synapse_table_optimized_proofread(
        segment_id=segment_id_target,
        split_index=split_index_target,
        syn_type = "postsyn",
        coordinates_nm = True,
        return_df=True)

    synapse_post_coord = synapse_post_df[
        ["synapse_x_nm","synapse_y_nm","synapse_z_nm"]].to_numpy().astype('float')

    if plot:
        print(f"Plotting: Spine Coordinates")
    spine_shaft_coords = nxu.spine_shaft_coordinates(
        G_postsyn,
        verbose = False,
        plot = plot,
        mesh = mesh_post,
    )

    if verbose:
        print(f"Total time for presyn proximity data = {time.time() - st}")

    return_dict = dict(
        # for attributes for computing proximities
        postsyn_skeleton_array = postsyn_skeleton_array,
        postsyn_width_array = postsyn_width_array,
        postsyn_comp_array = postsyn_comp_array,

        # for skeletal walk distance
        post_sk_vert=post_sk_vert,
        post_sk_edges=post_sk_edges,
        postsyn_starting_coords=postsyn_starting_coords,

        # for computing euclidean distance
        postsyn_soma_coord=postsyn_soma_coord,

        # attributes to be collected in the vicinity of contact
        synapse_post_coord=synapse_post_coord,
        spine_shaft_coords=spine_shaft_coords,
        
        #for ploting 
        mesh_post = mesh_post,
        G_postsyn_sk = None,

    )
    
    return return_dict

# %%
prox_data = pxu.proximity_pre_post(
    segment_id_pre = segment_id,
    split_index_pre = split_index,

    segment_id_post = segment_id_post,
    split_index_post = split_index_post,

    presyn_prox_data = presyn_prox_data,
    postsyn_prox_data = None,

    plot_proximities = False,
    verbose = verbose_inner,
    return_df = False
)
