# %%
# %load_ext autoreload
# %autoreload 2

# %%
"""
Purpose: Read a json into a dictionary

"""
# Out:
# '\nPurpose: Read a json into a dictionary\n\n'

# %%
import neurd
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# WARNING:root:Need to pip install caveclient to repair mesh with pychunkedgraph
# WARNING:root:Need to pip install caveclient to use dataset_name parameters
# /usr/local/lib/python3.8/dist-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /usr/local/lib/python3.8/dist-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /usr/local/lib/python3.8/dist-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /usr/local/lib/python3.8/dist-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
import json
from neurd import parameter_utils as pu
from pathlib import Path

# %%
import json
from datasci_tools import json_utils as jsu

jsu.json_to_dict(
    filepath = "./microns_config.json",
)

# %%
from neurd import spine_utils as spu
from neurd import parameter_utils as pu

mod_dict = pu.modes_global_param_and_attributes_dict_from_module(
module = spu,
verbose = False,
)


filepath = "./test.json"
jsu.dict_to_json_file(mod_dict,filepath)

# %% [markdown]
# # Want to edit a lot of the modules in a folder

# %%
final_dict = pu.modes_global_param_and_attributes_dict_all_modules(
    directory = Path(pu.__file__).parents[0],
    verbose = False
)

# %%
pu.global_param_and_attributes_dict_to_separate_mode_jsons(
    final_dict,
    verbose =True,
    filepath = "./configs"
)

# %%
from datasci_tools import json_utils as jsu
from datasci_tools import data_struct_utils as dsu

# %%
"""
Purpose: Want to read in 

"""

# %%
from neurd import motif_utils as motu
from neurd import spine_utils as spu



mot_dict = pu.modes_global_param_and_attributes_dict_from_module(
module = motu,
verbose = True,
)


spu_dict = pu.modes_global_param_and_attributes_dict_from_module(
module = spu,
verbose = True,
)

# %% [markdown]
# # Read in Json File and Setting

# %%
from neurd import apical_utils as apu

# %%
from datasci_tools import module_utils as modu
modu.set_global_parameters_and_attributes_by_data_type(
    apu,
    data_type = "h01"
)

apu.rotation_function_axon_alignment

# %%
from neurd import microns_volume_utils as mvu
apu.hvu = mvu

# %%
apu.hvu.data_interface.align_neuron_obj

# %%
apu.rotation_function_axon_alignment

# %%
"""
Things to consider:

Rotation functions are functions inside of modules and won't get exported to json
hdju

Want the user to be able to set them with the json

"""

# %%
from datasci_tools import general_utils as gu
gu.merge_dicts

# %% [markdown]
# # Setting the parameters

# %%
"""
Purpose: To read in the json file 
"""

# %%
obj = pu.ModuleParameters(
    global_parameters=dict(x = 10,y = 20),
    attributes = dict(my_att = 10)
)

obj.global_parameters,obj.attributes,obj.global_parameters_with_suffix
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_data', 'attributes', 'get_paramater_type', 'global_parameters', 'global_parameters_with_suffix', 'set_parameter']
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[30], line 6
#       1 obj = pu.ModuleParameters(
#       2     global_parameters=dict(x = 10,y = 20),
#       3     attributes = dict(my_att = 10)
#       4 )
# ----> 6 obj.global_parameters,obj.attributes,obj.global_parameters_with_suffix
#
# File /neurd_packages/NEURD/neurd/parameter_utils.py:79, in ModuleParameters.__getattr__(self, k)
#      77     return self._data[k]
#      78 else:
# ---> 79     raise Exception("")
#
# Exception:

# %% [markdown]
# # Purpose: Want to process any form of data input

# %%
def process_nested_dict(
    data,
    strip_suffixes = True):
    """
    Purpose: To get a nested dictionary stripped down
    """
    if isinstance(data,Parameters):
        return data._dict.copy()

# %%
json
# Out:
# [{'apical_utils': 3}]

# %%
from datasci_tools import json_utils as jsu
from datasci_tools import general_utils as gu

def json_to_flat_dict(filepath):
    json = jsu.json_to_dict(filepath)
    return gu.flatten_nested_dict(json)
# Out:
# {'soma_angle_to_apical': 60,
#  'multi_apical_height': -460000,
#  'max_upward_angle_shaft_like': 30,
#  'min_upward_length_shaft_like': 3000,
#  'min_upward_per_match_shaft_like': 0.8,
#  'min_upward_length_backup_shaft_like': 20000,
#  'min_upward_per_match_backup_shaft_like': 0.5,
#  'width_min_shaft_like': 140,
#  'min_skeletal_length_filter_apical': 10000,
#  'min_distance_above_soma_filter_apical': 10000,
#  'candidate_connected_component_radius_apical': 5000,
#  'multi_apical_possible_apical': True,
#  'width_min_apical_high_soma': 450,
#  'distance_from_soma_apical_high_soma': 80000,
#  'min_thick_near_soma_skeletal_length_apical_high_soma': 10000,
#  'non_upward_skeletal_distance_upstream_buffer_filter_apical_one': -10000,
#  'soma_diff_buffer_filter_apical_one': -50000,
#  'downstream_vector_diff_buffer_filter_apical_one': -30000,
#  'default_tie_breaker_filter_apical_one': 'skeletal_length',
#  'add_low_degree_apicals_off_shaft_tuft': False,
#  'low_degree_apicals_min_angle_tuft': 0,
#  'low_degree_apicals_max_angle_tuft': 40,
#  'min_angle_oblique': 80,
#  'max_angle_oblique': 140,
#  'per_match_ref_vector_min_oblique': 0.8,
#  'dist_match_ref_vector_min_oblique': 10000,
#  'rotation_function_axon_alignment': None,
#  'unrotation_function_axon_alignment': None,
#  'width_max_ax_on_dendr': 270,
#  'n_spines_max_ax_on_dendr': 10,
#  'n_synapses_post_spine_max_ax_on_dendr': 3,
#  'n_synapses_pre_min_ax_on_dendr': 1,
#  'synapse_pre_perc_min_ax_on_dendr': 0.6,
#  'synapse_pre_perc_downstream_min_ax_on_dendr': 0.9,
#  'axon_skeletal_legnth_min_ax_on_dendr': 2500,
#  'filter_away_thin_branches_ax_on_dendr': True,
#  'dendrite_width_min_ax_on_dendr': 80,
#  'thin_axon_skeletal_length_min_ax_on_dendr': 2500,
#  'thin_axon_n_synapses_post_downstream_max_ax_on_dendr': 3,
#  'mesh_area_min_ax_on_dendr': 1,
#  'closest_mesh_skeleton_dist_max_ax_on_dendr': 500,
#  'filter_away_myelination_myelin': True,
#  'min_skeletal_length_myelin': 5000,
#  'max_synapse_density_myelin': 7e-05,
#  'max_synapse_density_pass_2_myelin': 0.0001,
#  'min_skeletal_length_pass_2_myelin': 25000,
#  'min_distance_from_soma_pass_2_myelin': -1,
#  'max_width_myelin': 650,
#  'min_distance_from_soma_myelin': 10000,
#  'skeletal_length_downstream_min_ax_on_dendr': 7000,
#  'n_synapses_post_downstream_max_myelin': 5,
#  'max_bouton_width_to_check': 120,
#  'min_size_threshold_bouton': 27,
#  'max_size_threshold_bouton': 350,
#  'ray_trace_threshold_bouton': 200,
#  'split_significance_threshold_web': 20,
#  'maximum_volume_threshold_web': 3000,
#  'minimum_volume_threshold_web': 20,
#  'min_distance_from_soma_inhibitory_dendr_on_axon': 10000,
#  'min_distance_from_soma_excitatory_dendr_on_axon': 10000,
#  'n_synapses_pre_min_dendr_on_axon': 1,
#  'synapse_post_perc_min_dendr_on_axon': 0.6,
#  'spine_density_min_dendr_on_axon': 0.00012,
#  'dendrite_width_min_dendr_on_axon': 170,
#  'dendrite_skeletal_length_min_dendr_on_axon': 3000,
#  'coarse_dendrite_filter': True,
#  'coarse_dendrite_axon_width_min': 300,
#  'coarse_dendrite_synapse_post_perc_min': 0.75,
#  'coarse_dendrite_n_synapses_post_min': 20,
#  'coarse_dendrite_n_spines_min': 10,
#  'coarse_dendrtie_spine_density': 0.00015,
#  'synapse_post_perc_downstream_min_dendr_on_axon': 0.9,
#  'n_synapses_pre_downstream_max_dendr_on_axon': 3,
#  'filter_away_spiney_branches_dendr_on_axon': False,
#  'n_synapses_post_spine_max_dendr_on_axon': 4,
#  'spine_density_max_dendr_on_axon': 0.00015,
#  'max_ais_distance_from_soma': 50000,
#  'offset_skeleton_vector': 500,
#  'comparison_distance_skeleton_vector': 3000,
#  'lower_width_bound_spine': 140,
#  'upper_width_bound_spine': 520,
#  'apply_hand_made_low_rules': False,
#  'skeletal_length_processed_syn_min': 15000,
#  'skeletal_length_processed_spine_min': 15000,
#  'inhibitory_syn_density_shaft_min': 0.4,
#  'spine_threshold_syn_density': -1,
#  'skeletal_length_threshold_syn_density': 5000,
#  'upper_width_bound_syn_density': 10000,
#  'non_ais_width_axon': 200,
#  'ais_width_axon': 600,
#  'max_n_spines_axon': 7,
#  'max_spine_density_axon': 8e-05,
#  'apply_width_filter': True,
#  'best_match_width_diff_max': 75,
#  'best_match_width_diff_max_perc': 0.6,
#  'best_match_width_diff_min': 0.25,
#  'no_non_cut_disconnected_comps': True,
#  'best_singular_match': True,
#  'lowest_angle_sum_for_pairs': False,
#  'skip_distance_high_degree_dendr': 1200,
#  'width_max_high_degree_dendr': 300,
#  'upstream_width_max_high_degree_dendr': 300,
#  'offset_high_degree_dendr': 1500,
#  'comparison_distance_high_degree_dendr': 3000,
#  'width_diff_max_high_degree_dendr': 150,
#  'perform_synapse_filter_high_degree_dendr': False,
#  'width_diff_perc_threshold_high_d_match_dendr': 0.15,
#  'width_diff_perc_buffer_high_d_match_dendr': 0.2,
#  'use_high_degree_false_positive_filter_dendr': False,
#  'min_skeletal_length_endpoints_high_degree_dendr': 8000,
#  'min_distance_from_soma_mesh_high_degree_dendr': 7000,
#  'double_back_threshold_axon_thick': 120,
#  'double_back_threshold_axon_thin': 127,
#  'child_width_maximum_ax_web_ax_web': 75,
#  'parent_width_maximum_ax_web': 75,
#  'child_skeletal_threshold_ax_web': 3000,
#  'child_skeletal_threshold_total_ax_web': 10000,
#  'child_angle_max_ax_web': 40,
#  'web_size_threshold_ax_web': 120,
#  'web_size_type_ax_web': 'ray_trace_median',
#  'web_above_threshold_ax_web': True,
#  'parent_width_maximum_thick_t': 70,
#  'min_child_width_max_thick_t': 78,
#  'child_skeletal_threshold_thick_t': 3000,
#  'child_skeletal_threshold_total_thick_t': 10000,
#  'child_angle_max_thick_t': 40,
#  'branch_skeletal_length_min_ax_double_b': 2000,
#  'total_downstream_skeleton_length_threshold_ax_double_b': 2000,
#  'upstream_skeletal_length_min_ax_double_b': 5000,
#  'axon_width_threshold_thin_ax_double_b': 180,
#  'axon_width_threshold_thick_ax_double_b': 180,
#  'downstream_width_max_fork_div': 90,
#  'upstream_width_max_fork_div': 90,
#  'total_downstream_skeleton_length_threshold_fork_div': 4000,
#  'individual_branch_length_threshold_fork_div': 3000,
#  'divergence_threshold_mean_fork_div': 160,
#  'comparison_distance_fork_div': 400,
#  'downstream_width_max_fork_min_dist': 90,
#  'upstream_width_max_fork_min_dist': 145,
#  'total_downstream_skeleton_length_threshold_fork_min_dist': 4000,
#  'individual_branch_length_threshold_fork_min_dist': 4000,
#  'min_distance_threshold_fork_min_dist': 550,
#  'upstream_width_threshold_ax_spine_at_inters': 110,
#  'downstream_width_threshold_ax_spine_at_inters': 150,
#  'child_skeletal_threshold_total_ax_spine_at_inters': 10000,
#  'upstream_width_threshold_min_syn_dist': 110,
#  'downstream_width_threshold_min_syn_dist': 150,
#  'min_synape_dist_min_syn_dist': 1300,
#  'branch_skeletal_length_min_double_b_axon_inh': 2000,
#  'total_downstream_skeleton_length_threshold_double_b_axon_inh': 2000,
#  'upstream_skeletal_length_min_double_b_axon_inh': 5000,
#  'axon_width_threshold_thin_double_b_axon_inh': 180,
#  'axon_width_threshold_thick_double_b_axon_inh': 180,
#  'attempt_upstream_pair_singular_double_b_axon_inh': True,
#  'skeletal_length_max_n_spines': 3000,
#  'width_threshold_MAP': 500,
#  'size_threshold_MAP': 2000,
#  'size_threshold_MAP_stitch': 2000,
#  'apply_expansion': False,
#  'max_stitch_distance': 8000,
#  'max_stitch_distance_CGAL': 5000,
#  'filter_end_node_length': 4000,
#  'use_adaptive_invalidation_d': False,
#  'use_adaptive_invalidation_d_floating': True,
#  'axon_width_preprocess_limb_max': 200,
#  'limb_remove_mesh_interior_face_threshold': 0,
#  'surface_reconstruction_size': 1000,
#  'floating_piece_face_threshold': 50,
#  'invalidation_d': 12000,
#  'remove_mesh_interior_face_threshold': 0,
#  'width_max_high_low_degree_inh': 140,
#  'upstream_width_max_high_low_degree_inh': 180,
#  'max_degree_to_resolve_absolute_low_degree_inh': 5,
#  'width_max_high_high_degree_inh_dendr': 500,
#  'upstream_width_max_high_high_degree_inh_dendr': 500,
#  'dendrite_branching_filters': False,
#  'dendrite_branching_filters_inh': False,
#  'double_back_threshold_inh_double_b': None,
#  'max_skeletal_length_low_branch_clusters_dendrite': 8000,
#  'min_n_nodes_in_cluster_low_branch_clusters_dendrite': 16,
#  'max_skeletal_length_low_branch_clusters_axon': 8000,
#  'min_n_nodes_in_cluster_low_branch_clusters_axon': 16,
#  'skeletal_distance_from_soma_min_axon': 10000,
#  'n_red_points_red_blue': 3,
#  'include_one_hop_downstream_error_branches_red_blue': True,
#  'one_hop_downstream_error_branches_max_distance_red_blue': 4000,
#  'offset_distance_for_points_valid_red_blue': 3000,
#  'offset_distance_for_points_error_red_blue': 3000,
#  'n_points_red_blue': 1,
#  'n_blue_points_red_blue': 2,
#  'red_blue_points_method_red_blue': 'closest_mesh_face',
#  'pair_conn_comp_by_common_upstream_red_blue': True,
#  'pair_conn_comp_errors_red_blue': True,
#  'group_all_conn_comp_together_red_blue': False,
#  'only_outermost_branches_red_blue': True,
#  'min_error_downstream_length_total_red_blue': 5000,
#  'split_red_blue_by_common_upstream_red_blue': True,
#  'use_undirected_graph_red_blue': False,
#  'avoid_one_red_or_blue_red_blue': True,
#  'min_cancel_distance_absolute_red_blue': 1000,
#  'remove_segment_threshold': 1500,
#  'remove_segment_threshold_round_2': 2500,
#  'consider_path_neighbors_for_removal': True,
#  'offset_high_degree': 2000,
#  'comparison_distance_high_degree': 2000,
#  'match_threshold_high_degree': 65,
#  'skip_small_soma_connectors': True,
#  'small_soma_connectors_skeletal_threshold': 2500,
#  'double_back_threshold': 80,
#  'offset_double_back': 1000,
#  'comparison_distance_double_back': 6000,
#  'width_jump_threshold': 200,
#  'simple_path_of_2_cut': False,
#  'apply_double_back_first': True,
#  'double_back_threshold_at_first': 110,
#  'min_skeletal_length_limb': 15000,
#  'head_smoothness': 0.09,
#  'head_ray_trace_min': 240,
#  'head_face_min': 10,
#  'only_allow_one_connected_component_neck': False,
#  'query': 'median_mesh_center > 115 and n_faces_branch>100',
#  'calculate_spine_volume': True,
#  'clusters_threshold': 5,
#  'smoothness_threshold': 0.08,
#  'shaft_close_hole_area_top_2_mean_max': 110000,
#  'shaft_mesh_volume_max': 300000000.0,
#  'shaft_mesh_n_faces_min': 10,
#  'shaft_threshold': 300,
#  'spine_n_face_threshold_bare_min': 6,
#  'spine_sk_length_threshold_bare_min': 306.6,
#  'filter_by_volume_threshold_bare_min': 900496.186,
#  'bbox_oriented_side_max_min_bare_min': 300,
#  'spine_volume_to_spine_area_min_bare_min': 0.008,
#  'sdf_mean_min_bare_min': 0,
#  'spine_n_face_threshold': 25,
#  'spine_sk_length_threshold': 1000,
#  'filter_by_bounding_box_longest_side_length': True,
#  'side_length_threshold': 5000,
#  'filter_out_border_spines': False,
#  'skeleton_endpoint_nullification': True,
#  'skeleton_endpoint_nullification_distance': 2000,
#  'soma_vertex_nullification': True,
#  'border_percentage_threshold': 0.3,
#  'check_spine_border_perc': 0.4,
#  'filter_by_volume': True,
#  'filter_by_volume_threshold': 19835293}

# %%
from neurd import parameter_utils as paru

filepath = "./configs/default_config-Copy1.json"
p_obj = paru.PackageParameters(filepath)
print(p_obj)
# Out:
#        ---apical_utils.py---
# {
#     "soma_angle_to_apical": 60,
#     "multi_apical_height": -460000,
#     "max_upward_angle_shaft_like": 30,
#     "min_upward_length_shaft_like": 3000,
#     "min_upward_per_match_shaft_like": 0.8,
#     "min_upward_length_backup_shaft_like": 20000,
#     "min_upward_per_match_backup_shaft_like": 0.5,
#     "width_min_shaft_like": 140,
#     "min_skeletal_length_filter_apical": 10000,
#     "min_distance_above_soma_filter_apical": 10000,
#     "candidate_connected_component_radius_apical": 5000,
#     "multi_apical_possible_apical": true,
#     "width_min_apical_high_soma": 450,
#     "distance_from_soma_apical_high_soma": 80000,
#     "min_thick_near_soma_skeletal_length_apical_high_soma": 10000,
#     "non_upward_skeletal_distance_upstream_buffer_filter_apical_one": -10000,
#     "soma_diff_buffer_filter_apical_one": -50000,
#     "downstream_vector_diff_buffer_filter_apical_one": -30000,
#     "default_tie_breaker_filter_apical_one": "skeletal_length",
#     "add_low_degree_apicals_off_shaft_tuft": false,
#     "low_degree_apicals_min_angle_tuft": 0,
#     "low_degree_apicals_max_angle_tuft": 40,
#     "min_angle_oblique": 80,
#     "max_angle_oblique": 140,
#     "per_match_ref_vector_min_oblique": 0.8,
#     "dist_match_ref_vector_min_oblique": 10000,
#     "rotation_function_axon_alignment": null,
#     "unrotation_function_axon_alignment": null
# }
#        ---axon_utils.py---
# {
#     "width_max_ax_on_dendr": 270,
#     "n_spines_max_ax_on_dendr": 10,
#     "n_synapses_post_spine_max_ax_on_dendr": 3,
#     "n_synapses_pre_min_ax_on_dendr": 1,
#     "synapse_pre_perc_min_ax_on_dendr": 0.6,
#     "synapse_pre_perc_downstream_min_ax_on_dendr": 0.9,
#     "axon_skeletal_legnth_min_ax_on_dendr": 2500,
#     "filter_away_thin_branches_ax_on_dendr": true,
#     "dendrite_width_min_ax_on_dendr": 80,
#     "thin_axon_skeletal_length_min_ax_on_dendr": 2500,
#     "thin_axon_n_synapses_post_downstream_max_ax_on_dendr": 3,
#     "mesh_area_min_ax_on_dendr": 1,
#     "closest_mesh_skeleton_dist_max_ax_on_dendr": 500,
#     "filter_away_myelination_myelin": true,
#     "min_skeletal_length_myelin": 5000,
#     "max_synapse_density_myelin": 7e-05,
#     "max_synapse_density_pass_2_myelin": 0.0001,
#     "min_skeletal_length_pass_2_myelin": 25000,
#     "min_distance_from_soma_pass_2_myelin": -1,
#     "max_width_myelin": 650,
#     "min_distance_from_soma_myelin": 10000,
#     "skeletal_length_downstream_min_ax_on_dendr": 7000,
#     "n_synapses_post_downstream_max_myelin": 5,
#     "max_bouton_width_to_check": 120,
#     "min_size_threshold_bouton": 27,
#     "max_size_threshold_bouton": 350,
#     "ray_trace_threshold_bouton": 200,
#     "split_significance_threshold_web": 20,
#     "maximum_volume_threshold_web": 3000,
#     "minimum_volume_threshold_web": 20,
#     "min_distance_from_soma_inhibitory_dendr_on_axon": 10000,
#     "min_distance_from_soma_excitatory_dendr_on_axon": 10000,
#     "n_synapses_pre_min_dendr_on_axon": 1,
#     "synapse_post_perc_min_dendr_on_axon": 0.6,
#     "spine_density_min_dendr_on_axon": 0.00012,
#     "dendrite_width_min_dendr_on_axon": 170,
#     "dendrite_skeletal_length_min_dendr_on_axon": 3000,
#     "coarse_dendrite_filter": true,
#     "coarse_dendrite_axon_width_min": 300,
#     "coarse_dendrite_synapse_post_perc_min": 0.75,
#     "coarse_dendrite_n_synapses_post_min": 20,
#     "coarse_dendrite_n_spines_min": 10,
#     "coarse_dendrtie_spine_density": 0.00015,
#     "synapse_post_perc_downstream_min_dendr_on_axon": 0.9,
#     "n_synapses_pre_downstream_max_dendr_on_axon": 3,
#     "filter_away_spiney_branches_dendr_on_axon": false,
#     "n_synapses_post_spine_max_dendr_on_axon": 4,
#     "spine_density_max_dendr_on_axon": 0.00015,
#     "rotation_function_axon_alignment": null,
#     "unrotation_function_axon_alignment": null,
#     "max_ais_distance_from_soma": 50000
# }
#        ---branch_utils.py---
# {
#     "offset_skeleton_vector": 500,
#     "comparison_distance_skeleton_vector": 3000
# }
#        ---cell_type_utils.py---
# {
#     "lower_width_bound_spine": 140,
#     "upper_width_bound_spine": 520,
#     "apply_hand_made_low_rules": false,
#     "skeletal_length_processed_syn_min": 15000,
#     "skeletal_length_processed_spine_min": 15000,
#     "inhibitory_syn_density_shaft_min": 0.4,
#     "spine_threshold_syn_density": -1,
#     "skeletal_length_threshold_syn_density": 5000,
#     "upper_width_bound_syn_density": 10000
# }
#        ---classification_utils.py---
# {
#     "non_ais_width_axon": 200,
#     "ais_width_axon": 600,
#     "max_n_spines_axon": 7,
#     "max_spine_density_axon": 8e-05
# }
#        ---connectome_query_utils.py---
# {}
#        ---connectome_utils.py---
# {}
#        ---error_detection.py---
# {
#     "apply_width_filter": true,
#     "best_match_width_diff_max": 75,
#     "best_match_width_diff_max_perc": 0.6,
#     "best_match_width_diff_min": 0.25,
#     "no_non_cut_disconnected_comps": true,
#     "best_singular_match": true,
#     "lowest_angle_sum_for_pairs": false,
#     "skip_distance_high_degree_dendr": 1200,
#     "width_max_high_degree_dendr": 300,
#     "upstream_width_max_high_degree_dendr": 300,
#     "offset_high_degree_dendr": 1500,
#     "comparison_distance_high_degree_dendr": 3000,
#     "width_diff_max_high_degree_dendr": 150,
#     "perform_synapse_filter_high_degree_dendr": false,
#     "width_diff_perc_threshold_high_d_match_dendr": 0.15,
#     "width_diff_perc_buffer_high_d_match_dendr": 0.2,
#     "use_high_degree_false_positive_filter_dendr": false,
#     "min_skeletal_length_endpoints_high_degree_dendr": 8000,
#     "min_distance_from_soma_mesh_high_degree_dendr": 7000,
#     "double_back_threshold_axon_thick": 120,
#     "double_back_threshold_axon_thin": 127
# }
#        ---graph_filters.py---
# {
#     "child_width_maximum_ax_web_ax_web": 75,
#     "parent_width_maximum_ax_web": 75,
#     "child_skeletal_threshold_ax_web": 3000,
#     "child_skeletal_threshold_total_ax_web": 10000,
#     "child_angle_max_ax_web": 40,
#     "web_size_threshold_ax_web": 120,
#     "web_size_type_ax_web": "ray_trace_median",
#     "web_above_threshold_ax_web": true,
#     "parent_width_maximum_thick_t": 70,
#     "min_child_width_max_thick_t": 78,
#     "child_skeletal_threshold_thick_t": 3000,
#     "child_skeletal_threshold_total_thick_t": 10000,
#     "child_angle_max_thick_t": 40,
#     "branch_skeletal_length_min_ax_double_b": 2000,
#     "total_downstream_skeleton_length_threshold_ax_double_b": 2000,
#     "upstream_skeletal_length_min_ax_double_b": 5000,
#     "axon_width_threshold_thin_ax_double_b": 180,
#     "axon_width_threshold_thick_ax_double_b": 180,
#     "downstream_width_max_fork_div": 90,
#     "upstream_width_max_fork_div": 90,
#     "total_downstream_skeleton_length_threshold_fork_div": 4000,
#     "individual_branch_length_threshold_fork_div": 3000,
#     "divergence_threshold_mean_fork_div": 160,
#     "comparison_distance_fork_div": 400,
#     "downstream_width_max_fork_min_dist": 90,
#     "upstream_width_max_fork_min_dist": 145,
#     "total_downstream_skeleton_length_threshold_fork_min_dist": 4000,
#     "individual_branch_length_threshold_fork_min_dist": 4000,
#     "min_distance_threshold_fork_min_dist": 550,
#     "upstream_width_threshold_ax_spine_at_inters": 110,
#     "downstream_width_threshold_ax_spine_at_inters": 150,
#     "child_skeletal_threshold_total_ax_spine_at_inters": 10000,
#     "upstream_width_threshold_min_syn_dist": 110,
#     "downstream_width_threshold_min_syn_dist": 150,
#     "min_synape_dist_min_syn_dist": 1300,
#     "branch_skeletal_length_min_double_b_axon_inh": 2000,
#     "total_downstream_skeleton_length_threshold_double_b_axon_inh": 2000,
#     "upstream_skeletal_length_min_double_b_axon_inh": 5000,
#     "axon_width_threshold_thin_double_b_axon_inh": 180,
#     "axon_width_threshold_thick_double_b_axon_inh": 180,
#     "attempt_upstream_pair_singular_double_b_axon_inh": true
# }
#        ---motif_utils.py---
# {}
#        ---neuron_geometry_utils.py---
# {}
#        ---neuron_statistics.py---
# {}
#        ---neuron_utils.py---
# {
#     "skeletal_length_max_n_spines": 3000
# }
#        ---preprocessing_vp2.py---
# {
#     "width_threshold_MAP": 500,
#     "size_threshold_MAP": 2000,
#     "size_threshold_MAP_stitch": 2000,
#     "apply_expansion": false,
#     "max_stitch_distance": 8000,
#     "max_stitch_distance_CGAL": 5000,
#     "filter_end_node_length": 4000,
#     "use_adaptive_invalidation_d": false,
#     "use_adaptive_invalidation_d_floating": true,
#     "axon_width_preprocess_limb_max": 200,
#     "limb_remove_mesh_interior_face_threshold": 0,
#     "surface_reconstruction_size": 1000,
#     "floating_piece_face_threshold": 50,
#     "invalidation_d": 12000,
#     "remove_mesh_interior_face_threshold": 0
# }
#        ---proofreading_utils.py---
# {
#     "width_max_high_low_degree_inh": 140,
#     "upstream_width_max_high_low_degree_inh": 180,
#     "max_degree_to_resolve_absolute_low_degree_inh": 5,
#     "width_max_high_high_degree_inh_dendr": 500,
#     "upstream_width_max_high_high_degree_inh_dendr": 500,
#     "dendrite_branching_filters": false,
#     "dendrite_branching_filters_inh": false,
#     "double_back_threshold_inh_double_b": null,
#     "max_skeletal_length_low_branch_clusters_dendrite": 8000,
#     "min_n_nodes_in_cluster_low_branch_clusters_dendrite": 16,
#     "max_skeletal_length_low_branch_clusters_axon": 8000,
#     "min_n_nodes_in_cluster_low_branch_clusters_axon": 16,
#     "skeletal_distance_from_soma_min_axon": 10000,
#     "n_red_points_red_blue": 3,
#     "include_one_hop_downstream_error_branches_red_blue": true,
#     "one_hop_downstream_error_branches_max_distance_red_blue": 4000,
#     "offset_distance_for_points_valid_red_blue": 3000,
#     "offset_distance_for_points_error_red_blue": 3000,
#     "n_points_red_blue": 1,
#     "n_blue_points_red_blue": 2,
#     "red_blue_points_method_red_blue": "closest_mesh_face",
#     "pair_conn_comp_by_common_upstream_red_blue": true,
#     "pair_conn_comp_errors_red_blue": true,
#     "group_all_conn_comp_together_red_blue": false,
#     "only_outermost_branches_red_blue": true,
#     "min_error_downstream_length_total_red_blue": 5000,
#     "split_red_blue_by_common_upstream_red_blue": true,
#     "use_undirected_graph_red_blue": false,
#     "avoid_one_red_or_blue_red_blue": true,
#     "min_cancel_distance_absolute_red_blue": 1000,
#     "remove_segment_threshold": 1500,
#     "remove_segment_threshold_round_2": 2500,
#     "consider_path_neighbors_for_removal": true,
#     "offset_high_degree": 2000,
#     "comparison_distance_high_degree": 2000,
#     "match_threshold_high_degree": 65,
#     "skip_small_soma_connectors": true,
#     "small_soma_connectors_skeletal_threshold": 2500,
#     "double_back_threshold": 80,
#     "offset_double_back": 1000,
#     "comparison_distance_double_back": 6000,
#     "width_jump_threshold": 200,
#     "simple_path_of_2_cut": false,
#     "apply_double_back_first": true,
#     "double_back_threshold_at_first": 110,
#     "min_skeletal_length_limb": 15000
# }
#        ---proximity_analysis_utils.py---
# {}
#        ---proximity_utils.py---
# {}
#        ---soma_extraction_utils.py---
# {}
#        ---spine_utils.py---
# {
#     "head_smoothness": 0.09,
#     "head_ray_trace_min": 240,
#     "head_face_min": 10,
#     "only_allow_one_connected_component_neck": false,
#     "query": "median_mesh_center > 115 and n_faces_branch>100",
#     "calculate_spine_volume": true,
#     "clusters_threshold": 5,
#     "smoothness_threshold": 0.08,
#     "shaft_close_hole_area_top_2_mean_max": 110000,
#     "shaft_mesh_volume_max": 300000000.0,
#     "shaft_mesh_n_faces_min": 10,
#     "shaft_threshold": 300,
#     "spine_n_face_threshold_bare_min": 6,
#     "spine_sk_length_threshold_bare_min": 306.6,
#     "filter_by_volume_threshold_bare_min": 900496.186,
#     "bbox_oriented_side_max_min_bare_min": 300,
#     "spine_volume_to_spine_area_min_bare_min": 0.008,
#     "sdf_mean_min_bare_min": 0,
#     "spine_n_face_threshold": 25,
#     "spine_sk_length_threshold": 1000,
#     "filter_by_bounding_box_longest_side_length": true,
#     "side_length_threshold": 5000,
#     "filter_out_border_spines": false,
#     "skeleton_endpoint_nullification": true,
#     "skeleton_endpoint_nullification_distance": 2000,
#     "soma_vertex_nullification": true,
#     "border_percentage_threshold": 0.3,
#     "check_spine_border_perc": 0.4,
#     "filter_by_volume": true,
#     "filter_by_volume_threshold": 19835293
# }
#        ---synapse_utils.py---
# {}

# %%
p_obj.module_attr_map(
    module = apu,
    attr_list = ["multi_apical_height","candidate_connected_component_radius_apical","hdju"],
    verbose = True
)
# Out:
# Could not locate: hdju
# {'multi_apical_height': -460000,
#  'candidate_connected_component_radius_apical': 5000}

# %% [markdown]
# # Have a module ask for the parameters it needs

# %%
from datasci_tools import pathlib_utils as plu
from datasci_tools import package_utils as pku
module_names = pku.module_names_from_directories(
    "/neurd_packages/NEURD/neurd/",
)

for mod in module_names:
    
    try:
        exec(f"from neurd import {mod}")
        print(f"\n----{mod}-----")
        exec_str = f"curr_params = paru.paramater_list_from_module( \
        {mod}, \
        clean_dict=False, \
        att_types = ('attributes',), \
        )"
        exec(exec_str)
    except:
        continue
        
    for k in curr_params:
        print(f"{k}")
# Out:
# ----ais_utils-----
#
# ----apical_utils-----
# rotation_function_axon_alignment
# unrotation_function_axon_alignment
#
# ----axon_utils-----
# rotation_function_axon_alignment
# unrotation_function_axon_alignment
# max_ais_distance_from_soma
#
# ----branch_attr_utils-----
#
# ----branch_utils-----
#
# ----cell_type_conv_utils-----
#
# ----cell_type_utils-----
#
# ----classification_utils-----
# hdju
#
# ----concept_network_utils-----
#
# ----connectome_analysis_utils-----
#
# ----connectome_query_utils-----
# hdju
#
# ----connectome_utils-----
# hdju
#
# ----datajoint_motifs-----
#
# ----error_detection-----
# double_back_threshold_axon_thick
# double_back_threshold_axon_thin
#
# ----functional_tuning_utils-----
#
# ----graph_filters-----
# default_graph_filters
#
# ----h01_volume_utils-----
#
# ----limb_utils-----
#
# ----microns_graph_query_utils-----
#
# ----microns_volume_utils-----
#
# ----motif_null_utils-----
#
# ----motif_utils-----
# hdju
#
# ----nature_paper_plotting-----
#
# ----neuron_geometry_utils-----
# voxel_to_nm_scaling
# hdju
#
# ----neuron_searching-----
#
# ----neuron_simplification-----
#
# ----neuron_statistics-----
# voxel_to_nm_scaling
#
# ----neuron_utils-----
# data_voxel_adjustment
#
# ----neuron_visualizations-----
#
# ----parameter_utils-----
#
# ----preprocessing_vp2-----
#
# ----proofreading_utils-----
# hdu
#
# ----proximity_analysis_utils-----
# voxel_to_nm_scaling
# hdju
#
# ----proximity_utils-----
# voxel_to_nm_scaling
# hdju
#
# ----soma_extraction_utils-----
#
# ----soma_splitting_utils-----
#
# ----spine_utils-----
#
# ----synapse_utils-----
# voxel_to_nm_scaling
# hdju
#
# ----volume_utils-----
#
# ----whole_neuron_classifier_datajoint_adapted-----
#
# ----width_utils-----

# %%
# Get a dictionary of all parameters
from datasci_tools import json_utils as jsu
nest_dict = paru.modes_global_param_and_attributes_dict_all_modules(
    "/neurd_packages/NEURD/neurd",
    clean_dict = False,
    )["default"]


print(
    nest_dict
)
# Out:
# {'apical_utils': {'global_parameters': {'apical': {'soma_angle_to_apical': 60, 'multi_apical_height': -460000, 'max_upward_angle_shaft_like': 30, 'min_upward_length_shaft_like': 3000, 'min_upward_per_match_shaft_like': 0.8, 'min_upward_length_backup_shaft_like': 20000, 'min_upward_per_match_backup_shaft_like': 0.5, 'width_min_shaft_like': 140, 'min_skeletal_length_filter_apical': 10000, 'min_distance_above_soma_filter_apical': 10000, 'candidate_connected_component_radius_apical': 5000, 'multi_apical_possible_apical': True, 'width_min_apical_high_soma': 450, 'distance_from_soma_apical_high_soma': 80000, 'min_thick_near_soma_skeletal_length_apical_high_soma': 10000, 'non_upward_skeletal_distance_upstream_buffer_filter_apical_one': -10000, 'soma_diff_buffer_filter_apical_one': -50000, 'downstream_vector_diff_buffer_filter_apical_one': -30000, 'default_tie_breaker_filter_apical_one': 'skeletal_length', 'add_low_degree_apicals_off_shaft_tuft': False, 'low_degree_apicals_min_angle_tuft': 0, 'low_degree_apicals_max_angle_tuft': 40}, 'oblique': {'min_angle_oblique': 80, 'max_angle_oblique': 140, 'per_match_ref_vector_min_oblique': 0.8, 'dist_match_ref_vector_min_oblique': 10000}}, 'attributes': {'no_category': {'rotation_function_axon_alignment': None, 'unrotation_function_axon_alignment': None}}}, 'axon_utils': {'global_parameters': {'auto_proof': {'ray_trace_min_axon_spines': 270 (None), 'ray_trace_max_axon_spines': 1200 (None), 'skeletal_length_min_axon_spines': 1000 (None), 'skeletal_length_max_axon_spines': 6000 (None), 'n_synapses_pre_min_axon_spines': 1 (None), 'n_synapses_pre_max_axon_spines': 3 (None), 'n_faces_min_axon_spines': 90 (None), 'downstream_upstream_dist_diff_axon_spines': 1000 (None), 'downstream_dist_min_over_syn_axon_spines': 2000 (None), 'exclude_starting_nodes_axon_spines': True (None), 'width_min_threshold_short_thick': 120 (None), 'skeletal_length_max_threshold_short_thick': 3500 (None), 'ray_trace_threshold_short_thick': 350 (None), 'parent_width_threshold_short_thick': None (int unsigned), 'exclude_starting_nodes_short_thick': True (None), 'add_zero_width_segments_short_thick': True (None), 'width_min_threshold_parent_short_thick': 95 (None), 'width_global_min_threshold_parent_short_thick': 40 (None), }, 'axon_finding': {'axon_soma_angle_threshold_excitatory': 70 (None), 'ais_max_distance_from_soma_excitatory': 14000 (None), 'axon_classification_without_synapses_excitatory': False (None), 'axon_classification_without_synapses_if_no_candidate_excitatory': True (None), 'ais_max_distance_from_soma_inhibitory': 70000 (None), 'axon_soma_angle_threshold': None (int unsigned), 'ais_syn_density_max': 0.00015 (None), 'ais_syn_alternative_max': 2 (None), 'ais_n_syn_pre_max': 1 (None), 'ais_width_min': 95 (None), 'ais_width_max': 650 (None), 'max_search_distance': 80000 (None), 'min_skeletal_length': 10000 (None), 'n_postsyn_max': 15 (None), 'postsyn_distance': 10000 (None), 'ais_width_filter': True (None), 'ais_new_width_min': 140 (None), 'ais_new_width_min_inhibitory': 140 (None), 'ais_new_width_downstream_skeletal_length': 20000 (None), 'ais_max_distance_from_soma': None (int unsigned), 'n_synapses_spine_offset_endpoint_upstream_max': 3 (None), 'attempt_second_pass': True (None), 'ais_syn_density_max_backup': 0.0007 (None), 'ais_n_syn_pre_max_backup': 100 (None), 'max_search_distance_addition_backup': 0 (None), 'return_best_candidate': True (None), 'best_candidate_method': max_skeletal_length_above_threshold_and_buffer (None), 'max_skeletal_length_min': 50000 (None), 'max_skeletal_length_buffer': 20000 (None), 'significant_lowest_density_min_skeletal_length': 15000 (None), 'lowest_density_ratio': 4 (None), 'downstream_distance_for_axon_angle': 30000 (None), 'axon_classification_without_synapses_if_no_candidate': False (None), 'axon_classification_without_synapses': False (None), 'ais_syn_density_max_excitatory': None (None), 'ais_syn_density_max_backup_excitatory': None (None), 'candidate_downstream_postsyn_densit ...

# %%
from datasci_tools import data_struct_utils as dsu
ex_dict = dsu.DictType({"hello":5})
ex_dict
# Out:
# {'hello': 5 (None), }

# %%
from datasci_tools import general_utils as gu

gu.print_nested_dict(
    nest_dict
)
# Out:
# {
#   'apical_utils':
#   {
#     'global_parameters':
#     {
#       'apical':
#       {
#         'soma_angle_to_apical':60,
#         'multi_apical_height':-460000,
#         'max_upward_angle_shaft_like':30,
#         'min_upward_length_shaft_like':3000,
#         'min_upward_per_match_shaft_like':0.8,
#         'min_upward_length_backup_shaft_like':20000,
#         'min_upward_per_match_backup_shaft_like':0.5,
#         'width_min_shaft_like':140,
#         'min_skeletal_length_filter_apical':10000,
#         'min_distance_above_soma_filter_apical':10000,
#         'candidate_connected_component_radius_apical':5000,
#         'multi_apical_possible_apical':True,
#         'width_min_apical_high_soma':450,
#         'distance_from_soma_apical_high_soma':80000,
#         'min_thick_near_soma_skeletal_length_apical_high_soma':10000,
#         'non_upward_skeletal_distance_upstream_buffer_filter_apical_one':-10000,
#         'soma_diff_buffer_filter_apical_one':-50000,
#         'downstream_vector_diff_buffer_filter_apical_one':-30000,
#         'default_tie_breaker_filter_apical_one':'skeletal_length',
#         'add_low_degree_apicals_off_shaft_tuft':False,
#         'low_degree_apicals_min_angle_tuft':0,
#         'low_degree_apicals_max_angle_tuft':40,
#       },
#       'oblique':
#       {
#         'min_angle_oblique':80,
#         'max_angle_oblique':140,
#         'per_match_ref_vector_min_oblique':0.8,
#         'dist_match_ref_vector_min_oblique':10000,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'rotation_function_axon_alignment':None,
#         'unrotation_function_axon_alignment':None,
#       },
#     },
#   },
#   'axon_utils':
#   {
#     'global_parameters':
#     {
#       'auto_proof':
#       {
#         'ray_trace_min_axon_spines':270,
#         'ray_trace_max_axon_spines':1200,
#         'skeletal_length_min_axon_spines':1000,
#         'skeletal_length_max_axon_spines':6000,
#         'n_synapses_pre_min_axon_spines':1,
#         'n_synapses_pre_max_axon_spines':3,
#         'n_faces_min_axon_spines':90,
#         'downstream_upstream_dist_diff_axon_spines':1000,
#         'downstream_dist_min_over_syn_axon_spines':2000,
#         'exclude_starting_nodes_axon_spines':True,
#         'width_min_threshold_short_thick':120,
#         'skeletal_length_max_threshold_short_thick':3500,
#         'ray_trace_threshold_short_thick':350,
#         'parent_width_threshold_short_thick':None,
#         'exclude_starting_nodes_short_thick':True,
#         'add_zero_width_segments_short_thick':True,
#         'width_min_threshold_parent_short_thick':95,
#         'width_global_min_threshold_parent_short_thick':40,
#       },
#       'axon_finding':
#       {
#         'axon_soma_angle_threshold_excitatory':70,
#         'ais_max_distance_from_soma_excitatory':14000,
#         'axon_classification_without_synapses_excitatory':False,
#         'axon_classification_without_synapses_if_no_candidate_excitatory':True,
#         'ais_max_distance_from_soma_inhibitory':70000,
#         'axon_soma_angle_threshold':None,
#         'ais_syn_density_max':0.00015,
#         'ais_syn_alternative_max':2,
#         'ais_n_syn_pre_max':1,
#         'ais_width_min':95,
#         'ais_width_max':650,
#         'max_search_distance':80000,
#         'min_skeletal_length':10000,
#         'n_postsyn_max':15,
#         'postsyn_distance':10000,
#         'ais_width_filter':True,
#         'ais_new_width_min':140,
#         'ais_new_width_min_inhibitory':140,
#         'ais_new_width_downstream_skeletal_length':20000,
#         'ais_max_distance_from_soma':None,
#         'n_synapses_spine_offset_endpoint_upstream_max':3,
#         'attempt_second_pass':True,
#         'ais_syn_density_max_backup':0.0007,
#         'ais_n_syn_pre_max_backup':100,
#         'max_search_distance_addition_backup':0,
#         'return_best_candidate':True,
#         'best_candidate_method':'max_skeletal_length_above_threshold_and_buffer',
#         'max_skeletal_length_min':50000,
#         'max_skeletal_length_buffer':20000,
#         'significant_lowest_density_min_skeletal_length':15000,
#         'lowest_density_ratio':4,
#         'downstream_distance_for_axon_angle':30000,
#         'axon_classification_without_synapses_if_no_candidate':False,
#         'axon_classification_without_synapses':False,
#         'ais_syn_density_max_excitatory':None,
#         'ais_syn_density_max_backup_excitatory':None,
#         'candidate_downstream_postsyn_density_max':0.00015,
#       },
#       'axon_on_dendrite':
#       {
#         'width_max_ax_on_dendr':270,
#         'n_spines_max_ax_on_dendr':10,
#         'n_synapses_post_spine_max_ax_on_dendr':3,
#         'n_synapses_pre_min_ax_on_dendr':1,
#         'synapse_pre_perc_min_ax_on_dendr':0.6,
#         'synapse_pre_perc_downstream_min_ax_on_dendr':0.9,
#         'axon_skeletal_legnth_min_ax_on_dendr':2500,
#         'filter_away_thin_branches_ax_on_dendr':True,
#         'dendrite_width_min_ax_on_dendr':80,
#         'thin_axon_skeletal_length_min_ax_on_dendr':2500,
#         'thin_axon_n_synapses_post_downstream_max_ax_on_dendr':3,
#         'mesh_area_min_ax_on_dendr':1,
#         'closest_mesh_skeleton_dist_max_ax_on_dendr':500,
#         'filter_away_myelination_myelin':True,
#         'min_skeletal_length_myelin':5000,
#         'max_synapse_density_myelin':7e-05,
#         'max_synapse_density_pass_2_myelin':0.0001,
#         'min_skeletal_length_pass_2_myelin':25000,
#         'min_distance_from_soma_pass_2_myelin':-1,
#         'max_width_myelin':650,
#         'min_distance_from_soma_myelin':10000,
#         'skeletal_length_downstream_min_ax_on_dendr':7000,
#         'n_synapses_post_downstream_max_myelin':5,
#       },
#       'bouton_webbing':
#       {
#         'max_bouton_width_to_check':120,
#         'min_size_threshold_bouton':27,
#         'max_size_threshold_bouton':350,
#         'ray_trace_threshold_bouton':200,
#         'split_significance_threshold_web':20,
#         'maximum_volume_threshold_web':3000,
#         'minimum_volume_threshold_web':20,
#       },
#       'dendr_on_axon':
#       {
#         'min_distance_from_soma_inhibitory_dendr_on_axon':10000,
#         'min_distance_from_soma_excitatory_dendr_on_axon':10000,
#         'n_synapses_pre_min_dendr_on_axon':1,
#         'synapse_post_perc_min_dendr_on_axon':0.6,
#         'spine_density_min_dendr_on_axon':0.00012,
#         'dendrite_width_min_dendr_on_axon':170,
#         'dendrite_skeletal_length_min_dendr_on_axon':3000,
#         'coarse_dendrite_filter':True,
#         'coarse_dendrite_axon_width_min':300,
#         'coarse_dendrite_synapse_post_perc_min':0.75,
#         'coarse_dendrite_n_synapses_post_min':20,
#         'coarse_dendrite_n_spines_min':10,
#         'coarse_dendrtie_spine_density':0.00015,
#         'synapse_post_perc_downstream_min_dendr_on_axon':0.9,
#         'n_synapses_pre_downstream_max_dendr_on_axon':3,
#         'filter_away_spiney_branches_dendr_on_axon':False,
#         'n_synapses_post_spine_max_dendr_on_axon':4,
#         'spine_density_max_dendr_on_axon':0.00015,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'rotation_function_axon_alignment':None,
#         'unrotation_function_axon_alignment':None,
#         'max_ais_distance_from_soma':50000,
#       },
#     },
#   },
#   'branch_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#         'offset_skeleton_vector':500,
#         'comparison_distance_skeleton_vector':3000,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#       },
#     },
#   },
#   'cell_type_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#         'lower_width_bound_spine':140,
#         'upper_width_bound_spine':520,
#         'apply_hand_made_low_rules':False,
#         'skeletal_length_processed_syn_min':15000,
#         'skeletal_length_processed_spine_min':15000,
#         'inhibitory_syn_density_shaft_min':0.4,
#         'spine_threshold_syn_density':-1,
#         'skeletal_length_threshold_syn_density':5000,
#         'upper_width_bound_syn_density':10000,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#       },
#     },
#   },
#   'classification_utils':
#   {
#     'global_parameters':
#     {
#       'axon':
#       {
#         'non_ais_width_axon':200,
#         'ais_width_axon':600,
#         'max_n_spines_axon':7,
#         'max_spine_density_axon':8e-05,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
#   'connectome_query_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
#   'connectome_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
#   'error_detection':
#   {
#     'global_parameters':
#     {
#       'auto_proof':
#       {
#         'double_back_threshold_axon_thick_inh':135,
#         'double_back_threshold_axon_thin_inh':140,
#         'min_upstream_skeletal_distance':500,
#         'min_distance_from_soma_for_proof':10000,
#         'min_degree_to_resolve':3,
#         'max_degree_to_resolve_absolute':1000,
#         'max_degree_to_resolve':1000,
#         'max_degree_to_resolve_wide':1000,
#         'max_degree_to_resolve_width_threshold':200,
#         'width_min':35,
#         'width_max':170,
#         'upstream_width_max':None,
#         'axon_dependent':True,
#         'skip_distance_poly_x':(80, 200),
#         'skip_distance_poly_y':(1500, 2000),
#         'offset_high_d_match':1000,
#         'comparison_distance_high_d_match':2000,
#         'worst_case_sk_angle_match_threshold_high_d_match':65,
#         'width_diff_max_high_d_match':75,
#         'width_diff_perc_high_d_match':0.6,
#         'perform_synapse_filter_high_d_match':True,
#         'synapse_density_diff_threshold_high_d_match':0.00015,
#         'n_synapses_diff_threshold_high_d_match':6,
#         'sk_angle_match_threshold_high_d_match':45,
#         'sk_angle_buffer_high_d_match':25,
#         'width_diff_perc_threshold_high_d_match':0.15,
#         'width_diff_perc_buffer_high_d_match':0.3,
#         'kiss_check_high_d_match':False,
#         'kiss_check_bbox_longest_side_threshold_high_d_match':450,
#         'match_method_high_d_match':'all_error_if_not_one_match',
#         'use_exclusive_partner_high_d_match':True,
#         'use_high_degree_false_positive_filter':True,
#         'width_min_high_degree_false_positive':250,
#         'sibling_skeletal_angle_max_high_degree_false_positive':110,
#         'skip_distance_low_d_match':0,
#         'min_upstream_skeletal_distance_low_d_match':2000,
#         'min_degree_to_resolve_low_d_match':2,
#         'max_degree_to_resolve_wide_low_d_match':3,
#         'max_degree_to_resolve_absolute_low_d_match':1000,
#         'max_degree_to_resolve_low_d_match':3,
#         'width_max_low_d_match':170,
#         'upstream_width_max_low_d_match':None,
#         'offset_low_d_match':1000,
#         'comparison_distance_low_d_match':2000,
#         'worst_case_sk_angle_match_threshold_low_d_match':65,
#         'width_diff_max_low_d_match':75,
#         'width_diff_perc_low_d_match':0.6,
#         'perform_synapse_filter_low_d_match':True,
#         'synapse_density_diff_threshold_low_d_match':0.00015,
#         'n_synapses_diff_threshold_low_d_match':6,
#         'width_max_dendr_restr':500,
#         'width_max_dendr_double_back_restr':500,
#         'upstream_skeletal_length_min_dendr_restr':5000,
#         'upstream_skeletal_length_min_width_j_dendr':5000,
#         'branch_skeletal_length_min_width_j_dendr':7000,
#         'upstream_skeletal_length_min_for_min_width_j_dendr':4000,
#         'width_jump_max_width_j_dendr':200,
#         'upstream_skeletal_length_min_width_j_axon':5000,
#         'branch_skeletal_length_min_width_j_axon':8000,
#         'upstream_skeletal_length_min_for_min_width_j_axon':4000,
#         'width_jump_max_width_j_axon':55,
#         'axon_width_threshold_max_width_j_axon':100,
#         'double_back_threshold_double_b_dendrite':120,
#         'comparison_distance_double_b_dendrite':3000,
#         'offset_double_b_dendrite':0,
#         'branch_skeletal_length_min_double_b_dendrite':7000,
#       },
#       'crossover':
#       {
#         'apply_width_filter':True,
#         'best_match_width_diff_max':75,
#         'best_match_width_diff_max_perc':0.6,
#         'best_match_width_diff_min':0.25,
#         'no_non_cut_disconnected_comps':True,
#         'best_singular_match':True,
#         'lowest_angle_sum_for_pairs':False,
#       },
#       'high_degree_dendr':
#       {
#         'skip_distance_high_degree_dendr':1200,
#         'width_max_high_degree_dendr':300,
#         'upstream_width_max_high_degree_dendr':300,
#         'offset_high_degree_dendr':1500,
#         'comparison_distance_high_degree_dendr':3000,
#         'width_diff_max_high_degree_dendr':150,
#         'perform_synapse_filter_high_degree_dendr':False,
#         'width_diff_perc_threshold_high_d_match_dendr':0.15,
#         'width_diff_perc_buffer_high_d_match_dendr':0.2,
#         'use_high_degree_false_positive_filter_dendr':False,
#         'min_skeletal_length_endpoints_high_degree_dendr':8000,
#         'min_distance_from_soma_mesh_high_degree_dendr':7000,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'double_back_threshold_axon_thick':120,
#         'double_back_threshold_axon_thin':127,
#       },
#     },
#   },
#   'graph_filters':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#         'child_width_maximum_ax_web_ax_web':75,
#         'parent_width_maximum_ax_web':75,
#         'child_skeletal_threshold_ax_web':3000,
#         'child_skeletal_threshold_total_ax_web':10000,
#         'child_angle_max_ax_web':40,
#         'web_size_threshold_ax_web':120,
#         'web_size_type_ax_web':'ray_trace_median',
#         'web_above_threshold_ax_web':True,
#         'parent_width_maximum_thick_t':70,
#         'min_child_width_max_thick_t':78,
#         'child_skeletal_threshold_thick_t':3000,
#         'child_skeletal_threshold_total_thick_t':10000,
#         'child_angle_max_thick_t':40,
#         'branch_skeletal_length_min_ax_double_b':2000,
#         'total_downstream_skeleton_length_threshold_ax_double_b':2000,
#         'upstream_skeletal_length_min_ax_double_b':5000,
#         'axon_width_threshold_thin_ax_double_b':180,
#         'axon_width_threshold_thick_ax_double_b':180,
#         'downstream_width_max_fork_div':90,
#         'upstream_width_max_fork_div':90,
#         'total_downstream_skeleton_length_threshold_fork_div':4000,
#         'individual_branch_length_threshold_fork_div':3000,
#         'divergence_threshold_mean_fork_div':160,
#         'comparison_distance_fork_div':400,
#         'downstream_width_max_fork_min_dist':90,
#         'upstream_width_max_fork_min_dist':145,
#         'total_downstream_skeleton_length_threshold_fork_min_dist':4000,
#         'individual_branch_length_threshold_fork_min_dist':4000,
#         'min_distance_threshold_fork_min_dist':550,
#         'upstream_width_threshold_ax_spine_at_inters':110,
#         'downstream_width_threshold_ax_spine_at_inters':150,
#         'child_skeletal_threshold_total_ax_spine_at_inters':10000,
#         'upstream_width_threshold_min_syn_dist':110,
#         'downstream_width_threshold_min_syn_dist':150,
#         'min_synape_dist_min_syn_dist':1300,
#         'branch_skeletal_length_min_double_b_axon_inh':2000,
#         'total_downstream_skeleton_length_threshold_double_b_axon_inh':2000,
#         'upstream_skeletal_length_min_double_b_axon_inh':5000,
#         'axon_width_threshold_thin_double_b_axon_inh':180,
#         'axon_width_threshold_thick_double_b_axon_inh':180,
#         'attempt_upstream_pair_singular_double_b_axon_inh':True,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'default_graph_filters':[<function axon_webbing_filter at 0x7fbe0ffc2e50>, <function thick_t_filter at 0x7fbe0ffcf1f0>, <function axon_double_back_filter at 0x7fbe0ffcf160>, <function fork_divergence_filter at 0x7fbe0ffcf040>, <function fork_min_skeletal_distance_filter at 0x7fbe0ffcf0d0>, <function axon_spine_at_intersection_filter at 0x7fbe0ffc2ee0>, <function min_synapse_dist_to_branch_point_filter at 0x7fbe0ffc2f70>],
#       },
#     },
#   },
#   'motif_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
#   'neuron_geometry_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'voxel_to_nm_scaling':array([ 4,  4, 40]),
#         'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
#   'neuron_statistics':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'voxel_to_nm_scaling':array([ 4,  4, 40]),
#       },
#     },
#   },
#   'neuron_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#         'skeletal_length_max_n_spines':3000,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'data_voxel_adjustment':array([ 4,  4, 40]),
#       },
#     },
#   },
#   'preprocessing_vp2':
#   {
#     'global_parameters':
#     {
#       'axon_decomp':
#       {
#         'combine_close_skeleton_nodes_threshold_meshparty_axon':1300,
#         'filter_end_node_length_meshparty_axon':1150,
#         'filter_end_node_length_axon':1150,
#         'invalidation_d_axon':1500,
#         'smooth_neighborhood_axon':0,
#         'meshparty_segment_size_axon':100,
#         'stitch_floating_axon_pieces':True,
#         'max_stitch_distance_high_fid_axon':5000,
#         'floating_piece_face_threshold_high_fid_axon':50,
#       },
#       'decomp':
#       {
#         'width_threshold_MAP':500,
#         'size_threshold_MAP':2000,
#         'size_threshold_MAP_stitch':2000,
#         'apply_expansion':False,
#         'max_stitch_distance':8000,
#         'max_stitch_distance_CGAL':5000,
#         'filter_end_node_length':4000,
#         'use_adaptive_invalidation_d':False,
#         'use_adaptive_invalidation_d_floating':True,
#         'axon_width_preprocess_limb_max':200,
#         'limb_remove_mesh_interior_face_threshold':0,
#         'surface_reconstruction_size':1000,
#         'floating_piece_face_threshold':50,
#         'invalidation_d':12000,
#         'remove_mesh_interior_face_threshold':0,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#       },
#     },
#   },
#   'proofreading_utils':
#   {
#     'global_parameters':
#     {
#       'auto_proof':
#       {
#         'width_max_high_low_degree_inh':140,
#         'upstream_width_max_high_low_degree_inh':180,
#         'max_degree_to_resolve_absolute_low_degree_inh':5,
#         'width_max_high_high_degree_inh_dendr':500,
#         'upstream_width_max_high_high_degree_inh_dendr':500,
#         'dendrite_branching_filters':False,
#         'dendrite_branching_filters_inh':False,
#         'double_back_threshold_inh_double_b':None,
#       },
#       'low_branch_clusters':
#       {
#         'max_skeletal_length_low_branch_clusters_dendrite':8000,
#         'min_n_nodes_in_cluster_low_branch_clusters_dendrite':16,
#         'max_skeletal_length_low_branch_clusters_axon':8000,
#         'min_n_nodes_in_cluster_low_branch_clusters_axon':16,
#         'skeletal_distance_from_soma_min_axon':10000,
#       },
#       'red_blue':
#       {
#         'n_red_points_red_blue':4,
#       },
#       'red_blue_multi_axon_on_dendrite':
#       {
#         'include_one_hop_downstream_error_branches_red_blue':True,
#         'one_hop_downstream_error_branches_max_distance_red_blue':1000,
#         'offset_distance_for_points_valid_red_blue':1700,
#         'offset_distance_for_points_error_red_blue':1000,
#         'n_points_red_blue':1,
#         'n_red_points_red_blue':3,
#         'n_blue_points_red_blue':2,
#         'red_blue_points_method_red_blue':'closest_mesh_face',
#         'pair_conn_comp_by_common_upstream_red_blue':True,
#         'pair_conn_comp_errors_red_blue':True,
#         'group_all_conn_comp_together_red_blue':False,
#         'only_outermost_branches_red_blue':True,
#         'min_error_downstream_length_total_red_blue':5000,
#         'split_red_blue_by_common_upstream_red_blue':True,
#         'use_undirected_graph_red_blue':False,
#         'avoid_one_red_or_blue_red_blue':True,
#         'min_cancel_distance_absolute_red_blue':1000,
#       },
#       'red_blue_multi_soma':
#       {
#         'include_one_hop_downstream_error_branches_red_blue':True,
#         'one_hop_downstream_error_branches_max_distance_red_blue':4000,
#         'offset_distance_for_points_valid_red_blue':3000,
#         'offset_distance_for_points_error_red_blue':3000,
#         'n_points_red_blue':1,
#         'n_red_points_red_blue':3,
#         'n_blue_points_red_blue':2,
#         'red_blue_points_method_red_blue':'closest_mesh_face',
#         'pair_conn_comp_by_common_upstream_red_blue':True,
#         'pair_conn_comp_errors_red_blue':True,
#         'group_all_conn_comp_together_red_blue':False,
#         'only_outermost_branches_red_blue':True,
#         'min_error_downstream_length_total_red_blue':5000,
#         'split_red_blue_by_common_upstream_red_blue':True,
#         'use_undirected_graph_red_blue':False,
#         'avoid_one_red_or_blue_red_blue':True,
#         'min_cancel_distance_absolute_red_blue':1000,
#       },
#       'split':
#       {
#         'remove_segment_threshold':1500,
#         'remove_segment_threshold_round_2':2500,
#         'consider_path_neighbors_for_removal':True,
#         'offset_high_degree':2000,
#         'comparison_distance_high_degree':2000,
#         'match_threshold_high_degree':65,
#         'skip_small_soma_connectors':True,
#         'small_soma_connectors_skeletal_threshold':2500,
#         'double_back_threshold':80,
#         'offset_double_back':1000,
#         'comparison_distance_double_back':6000,
#         'width_jump_threshold':200,
#         'simple_path_of_2_cut':False,
#         'apply_double_back_first':True,
#         'double_back_threshold_at_first':110,
#         'min_skeletal_length_limb':15000,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'hdu':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
#   'proximity_analysis_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'voxel_to_nm_scaling':array([ 4,  4, 40]),
#         'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
#   'proximity_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'voxel_to_nm_scaling':array([ 4,  4, 40]),
#         'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
#   'soma_extraction_utils':
#   {
#     'global_parameters':
#     {
#       'glia':
#       {
#         'glia_volume_threshold_in_um':2500,
#         'glia_n_faces_threshold':400000,
#         'glia_n_faces_min':100000,
#       },
#       'nuclei':
#       {
#         'nucleus_min':700,
#         'nucleus_max':None,
#       },
#       'soma':
#       {
#         'outer_decimation_ratio':0.25,
#         'large_mesh_threshold':20000,
#         'large_mesh_threshold_inner':13000,
#         'inner_decimation_ratio':0.25,
#         'max_fail_loops':10,
#         'remove_inside_pieces':True,
#         'size_threshold_to_remove':1000,
#         'pymeshfix_clean':False,
#         'check_holes_before_pymeshfix':False,
#         'second_poisson':False,
#         'soma_width_threshold':0.32,
#         'soma_size_threshold':9000,
#         'soma_size_threshold_max':1200000,
#         'volume_mulitplier':8,
#         'side_length_ratio_threshold':6,
#         'perform_pairing':False,
#         'backtrack_soma_mesh_to_original':True,
#         'backtrack_soma_size_threshold':8000,
#         'poisson_backtrack_distance_threshold':None,
#         'close_holes':False,
#         'boundary_vertices_threshold':None,
#         'last_size_threshold':2000,
#         'segmentation_at_end':True,
#         'largest_hole_threshold':17000,
#         'second_pass_size_threshold':None,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#       },
#     },
#   },
#   'spine_utils':
#   {
#     'global_parameters':
#     {
#       'head_neck_shaft':
#       {
#         'head_smoothness':0.09,
#         'head_ray_trace_min':240,
#         'head_face_min':10,
#         'only_allow_one_connected_component_neck':False,
#       },
#       'spine_identification':
#       {
#         'query':'median_mesh_center > 115 and n_faces_branch>100',
#         'calculate_spine_volume':True,
#         'clusters_threshold':5,
#         'smoothness_threshold':0.08,
#         'shaft_close_hole_area_top_2_mean_max':110000,
#         'shaft_mesh_volume_max':300000000.0,
#         'shaft_mesh_n_faces_min':10,
#         'shaft_threshold':300,
#         'spine_n_face_threshold_bare_min':6,
#         'spine_sk_length_threshold_bare_min':306.6,
#         'filter_by_volume_threshold_bare_min':900496.186,
#         'bbox_oriented_side_max_min_bare_min':300,
#         'spine_volume_to_spine_area_min_bare_min':0.008,
#         'sdf_mean_min_bare_min':0,
#         'spine_n_face_threshold':25,
#         'spine_sk_length_threshold':1000,
#         'filter_by_bounding_box_longest_side_length':True,
#         'side_length_threshold':5000,
#         'filter_out_border_spines':False,
#         'skeleton_endpoint_nullification':True,
#         'skeleton_endpoint_nullification_distance':2000,
#         'soma_vertex_nullification':True,
#         'border_percentage_threshold':0.3,
#         'check_spine_border_perc':0.4,
#         'filter_by_volume':True,
#         'filter_by_volume_threshold':19835293,
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#       },
#     },
#   },
#   'synapse_utils':
#   {
#     'global_parameters':
#     {
#       'no_category':
#       {
#       },
#     },
#     'attributes':
#     {
#       'no_category':
#       {
#         'voxel_to_nm_scaling':array([ 4,  4, 40]),
#         'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
#       },
#     },
#   },
# }

# %%
import numpy as np

my_dict = {
  'apical_utils':
  {
    'global_parameters':
    {
      'apical':
      {
        'soma_angle_to_apical':60,
        'multi_apical_height':-460000,
        'max_upward_angle_shaft_like':30,
        'min_upward_length_shaft_like':3000,
        'min_upward_per_match_shaft_like':0.8,
        'min_upward_length_backup_shaft_like':20000,
        'min_upward_per_match_backup_shaft_like':0.5,
        'width_min_shaft_like':140,
        'min_skeletal_length_filter_apical':10000,
        'min_distance_above_soma_filter_apical':10000,
        'candidate_connected_component_radius_apical':5000,
        'multi_apical_possible_apical':True,
        'width_min_apical_high_soma':450,
        'distance_from_soma_apical_high_soma':80000,
        'min_thick_near_soma_skeletal_length_apical_high_soma':10000,
        'non_upward_skeletal_distance_upstream_buffer_filter_apical_one':-10000,
        'soma_diff_buffer_filter_apical_one':-50000,
        'downstream_vector_diff_buffer_filter_apical_one':-30000,
        'default_tie_breaker_filter_apical_one':'skeletal_length',
        'add_low_degree_apicals_off_shaft_tuft':False,
        'low_degree_apicals_min_angle_tuft':0,
        'low_degree_apicals_max_angle_tuft':40,
      },
      'oblique':
      {
        'min_angle_oblique':80,
        'max_angle_oblique':140,
        'per_match_ref_vector_min_oblique':0.8,
        'dist_match_ref_vector_min_oblique':10000,
      },
    },
    'attributes':
    {
      'no_category':
      {
        'rotation_function_axon_alignment':None,
        'unrotation_function_axon_alignment':None,
      },
    },
  },
  'axon_utils':
  {
    'global_parameters':
    {
      'auto_proof':
      {
        'ray_trace_min_axon_spines':270,
        'ray_trace_max_axon_spines':1200,
        'skeletal_length_min_axon_spines':1000,
        'skeletal_length_max_axon_spines':6000,
        'n_synapses_pre_min_axon_spines':1,
        'n_synapses_pre_max_axon_spines':3,
        'n_faces_min_axon_spines':90,
        'downstream_upstream_dist_diff_axon_spines':1000,
        'downstream_dist_min_over_syn_axon_spines':2000,
        'exclude_starting_nodes_axon_spines':True,
        'width_min_threshold_short_thick':120,
        'skeletal_length_max_threshold_short_thick':3500,
        'ray_trace_threshold_short_thick':350,
        'parent_width_threshold_short_thick':None,
        'exclude_starting_nodes_short_thick':True,
        'add_zero_width_segments_short_thick':True,
        'width_min_threshold_parent_short_thick':95,
        'width_global_min_threshold_parent_short_thick':40,
      },
      'axon_finding':
      {
        'axon_soma_angle_threshold_excitatory':70,
        'ais_max_distance_from_soma_excitatory':14000,
        'axon_classification_without_synapses_excitatory':False,
        'axon_classification_without_synapses_if_no_candidate_excitatory':True,
        'ais_max_distance_from_soma_inhibitory':70000,
        'axon_soma_angle_threshold':None,
        'ais_syn_density_max':0.00015,
        'ais_syn_alternative_max':2,
        'ais_n_syn_pre_max':1,
        'ais_width_min':95,
        'ais_width_max':650,
        'max_search_distance':80000,
        'min_skeletal_length':10000,
        'n_postsyn_max':15,
        'postsyn_distance':10000,
        'ais_width_filter':True,
        'ais_new_width_min':140,
        'ais_new_width_min_inhibitory':140,
        'ais_new_width_downstream_skeletal_length':20000,
        'ais_max_distance_from_soma':None,
        'n_synapses_spine_offset_endpoint_upstream_max':3,
        'attempt_second_pass':True,
        'ais_syn_density_max_backup':0.0007,
        'ais_n_syn_pre_max_backup':100,
        'max_search_distance_addition_backup':0,
        'return_best_candidate':True,
        'best_candidate_method':'max_skeletal_length_above_threshold_and_buffer',
        'max_skeletal_length_min':50000,
        'max_skeletal_length_buffer':20000,
        'significant_lowest_density_min_skeletal_length':15000,
        'lowest_density_ratio':4,
        'downstream_distance_for_axon_angle':30000,
        'axon_classification_without_synapses_if_no_candidate':False,
        'axon_classification_without_synapses':False,
        'ais_syn_density_max_excitatory':None,
        'ais_syn_density_max_backup_excitatory':None,
        'candidate_downstream_postsyn_density_max':0.00015,
      },
      'axon_on_dendrite':
      {
        'width_max_ax_on_dendr':270,
        'n_spines_max_ax_on_dendr':10,
        'n_synapses_post_spine_max_ax_on_dendr':3,
        'n_synapses_pre_min_ax_on_dendr':1,
        'synapse_pre_perc_min_ax_on_dendr':0.6,
        'synapse_pre_perc_downstream_min_ax_on_dendr':0.9,
        'axon_skeletal_legnth_min_ax_on_dendr':2500,
        'filter_away_thin_branches_ax_on_dendr':True,
        'dendrite_width_min_ax_on_dendr':80,
        'thin_axon_skeletal_length_min_ax_on_dendr':2500,
        'thin_axon_n_synapses_post_downstream_max_ax_on_dendr':3,
        'mesh_area_min_ax_on_dendr':1,
        'closest_mesh_skeleton_dist_max_ax_on_dendr':500,
        'filter_away_myelination_myelin':True,
        'min_skeletal_length_myelin':5000,
        'max_synapse_density_myelin':7e-05,
        'max_synapse_density_pass_2_myelin':0.0001,
        'min_skeletal_length_pass_2_myelin':25000,
        'min_distance_from_soma_pass_2_myelin':-1,
        'max_width_myelin':650,
        'min_distance_from_soma_myelin':10000,
        'skeletal_length_downstream_min_ax_on_dendr':7000,
        'n_synapses_post_downstream_max_myelin':5,
      },
      'bouton_webbing':
      {
        'max_bouton_width_to_check':120,
        'min_size_threshold_bouton':27,
        'max_size_threshold_bouton':350,
        'ray_trace_threshold_bouton':200,
        'split_significance_threshold_web':20,
        'maximum_volume_threshold_web':3000,
        'minimum_volume_threshold_web':20,
      },
      'dendr_on_axon':
      {
        'min_distance_from_soma_inhibitory_dendr_on_axon':10000,
        'min_distance_from_soma_excitatory_dendr_on_axon':10000,
        'n_synapses_pre_min_dendr_on_axon':1,
        'synapse_post_perc_min_dendr_on_axon':0.6,
        'spine_density_min_dendr_on_axon':0.00012,
        'dendrite_width_min_dendr_on_axon':170,
        'dendrite_skeletal_length_min_dendr_on_axon':3000,
        'coarse_dendrite_filter':True,
        'coarse_dendrite_axon_width_min':300,
        'coarse_dendrite_synapse_post_perc_min':0.75,
        'coarse_dendrite_n_synapses_post_min':20,
        'coarse_dendrite_n_spines_min':10,
        'coarse_dendrtie_spine_density':0.00015,
        'synapse_post_perc_downstream_min_dendr_on_axon':0.9,
        'n_synapses_pre_downstream_max_dendr_on_axon':3,
        'filter_away_spiney_branches_dendr_on_axon':False,
        'n_synapses_post_spine_max_dendr_on_axon':4,
        'spine_density_max_dendr_on_axon':0.00015,
      },
    },
    'attributes':
    {
      'no_category':
      {
        'rotation_function_axon_alignment':None,
        'unrotation_function_axon_alignment':None,
        'max_ais_distance_from_soma':50000,
      },
    },
  },
  'branch_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
        'offset_skeleton_vector':500,
        'comparison_distance_skeleton_vector':3000,
      },
    },
    'attributes':
    {
      'no_category':
      {
      },
    },
  },
  'cell_type_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
        'lower_width_bound_spine':140,
        'upper_width_bound_spine':520,
        'apply_hand_made_low_rules':False,
        'skeletal_length_processed_syn_min':15000,
        'skeletal_length_processed_spine_min':15000,
        'inhibitory_syn_density_shaft_min':0.4,
        'spine_threshold_syn_density':-1,
        'skeletal_length_threshold_syn_density':5000,
        'upper_width_bound_syn_density':10000,
      },
    },
    'attributes':
    {
      'no_category':
      {
      },
    },
  },
  'classification_utils':
  {
    'global_parameters':
    {
      'axon':
      {
        'non_ais_width_axon':200,
        'ais_width_axon':600,
        'max_n_spines_axon':7,
        'max_spine_density_axon':8e-05,
      },
    },
    'attributes':
    {
      'no_category':
      {
        #'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
  'connectome_query_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
      },
    },
    'attributes':
    {
      'no_category':
      {
        #'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
  'connectome_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
      },
    },
    'attributes':
    {
      'no_category':
      {
        #'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
  'error_detection':
  {
    'global_parameters':
    {
      'auto_proof':
      {
        'double_back_threshold_axon_thick_inh':135,
        'double_back_threshold_axon_thin_inh':140,
        'min_upstream_skeletal_distance':500,
        'min_distance_from_soma_for_proof':10000,
        'min_degree_to_resolve':3,
        'max_degree_to_resolve_absolute':1000,
        'max_degree_to_resolve':1000,
        'max_degree_to_resolve_wide':1000,
        'max_degree_to_resolve_width_threshold':200,
        'width_min':35,
        'width_max':170,
        'upstream_width_max':None,
        'axon_dependent':True,
        'skip_distance_poly_x':(80, 200),
        'skip_distance_poly_y':(1500, 2000),
        'offset_high_d_match':1000,
        'comparison_distance_high_d_match':2000,
        'worst_case_sk_angle_match_threshold_high_d_match':65,
        'width_diff_max_high_d_match':75,
        'width_diff_perc_high_d_match':0.6,
        'perform_synapse_filter_high_d_match':True,
        'synapse_density_diff_threshold_high_d_match':0.00015,
        'n_synapses_diff_threshold_high_d_match':6,
        'sk_angle_match_threshold_high_d_match':45,
        'sk_angle_buffer_high_d_match':25,
        'width_diff_perc_threshold_high_d_match':0.15,
        'width_diff_perc_buffer_high_d_match':0.3,
        'kiss_check_high_d_match':False,
        'kiss_check_bbox_longest_side_threshold_high_d_match':450,
        'match_method_high_d_match':'all_error_if_not_one_match',
        'use_exclusive_partner_high_d_match':True,
        'use_high_degree_false_positive_filter':True,
        'width_min_high_degree_false_positive':250,
        'sibling_skeletal_angle_max_high_degree_false_positive':110,
        'skip_distance_low_d_match':0,
        'min_upstream_skeletal_distance_low_d_match':2000,
        'min_degree_to_resolve_low_d_match':2,
        'max_degree_to_resolve_wide_low_d_match':3,
        'max_degree_to_resolve_absolute_low_d_match':1000,
        'max_degree_to_resolve_low_d_match':3,
        'width_max_low_d_match':170,
        'upstream_width_max_low_d_match':None,
        'offset_low_d_match':1000,
        'comparison_distance_low_d_match':2000,
        'worst_case_sk_angle_match_threshold_low_d_match':65,
        'width_diff_max_low_d_match':75,
        'width_diff_perc_low_d_match':0.6,
        'perform_synapse_filter_low_d_match':True,
        'synapse_density_diff_threshold_low_d_match':0.00015,
        'n_synapses_diff_threshold_low_d_match':6,
        'width_max_dendr_restr':500,
        'width_max_dendr_double_back_restr':500,
        'upstream_skeletal_length_min_dendr_restr':5000,
        'upstream_skeletal_length_min_width_j_dendr':5000,
        'branch_skeletal_length_min_width_j_dendr':7000,
        'upstream_skeletal_length_min_for_min_width_j_dendr':4000,
        'width_jump_max_width_j_dendr':200,
        'upstream_skeletal_length_min_width_j_axon':5000,
        'branch_skeletal_length_min_width_j_axon':8000,
        'upstream_skeletal_length_min_for_min_width_j_axon':4000,
        'width_jump_max_width_j_axon':55,
        'axon_width_threshold_max_width_j_axon':100,
        'double_back_threshold_double_b_dendrite':120,
        'comparison_distance_double_b_dendrite':3000,
        'offset_double_b_dendrite':0,
        'branch_skeletal_length_min_double_b_dendrite':7000,
      },
      'crossover':
      {
        'apply_width_filter':True,
        'best_match_width_diff_max':75,
        'best_match_width_diff_max_perc':0.6,
        'best_match_width_diff_min':0.25,
        'no_non_cut_disconnected_comps':True,
        'best_singular_match':True,
        'lowest_angle_sum_for_pairs':False,
      },
      'high_degree_dendr':
      {
        'skip_distance_high_degree_dendr':1200,
        'width_max_high_degree_dendr':300,
        'upstream_width_max_high_degree_dendr':300,
        'offset_high_degree_dendr':1500,
        'comparison_distance_high_degree_dendr':3000,
        'width_diff_max_high_degree_dendr':150,
        'perform_synapse_filter_high_degree_dendr':False,
        'width_diff_perc_threshold_high_d_match_dendr':0.15,
        'width_diff_perc_buffer_high_d_match_dendr':0.2,
        'use_high_degree_false_positive_filter_dendr':False,
        'min_skeletal_length_endpoints_high_degree_dendr':8000,
        'min_distance_from_soma_mesh_high_degree_dendr':7000,
      },
    },
    'attributes':
    {
      'no_category':
      {
        'double_back_threshold_axon_thick':120,
        'double_back_threshold_axon_thin':127,
      },
    },
  },
  'graph_filters':
  {
    'global_parameters':
    {
      'no_category':
      {
        'child_width_maximum_ax_web_ax_web':75,
        'parent_width_maximum_ax_web':75,
        'child_skeletal_threshold_ax_web':3000,
        'child_skeletal_threshold_total_ax_web':10000,
        'child_angle_max_ax_web':40,
        'web_size_threshold_ax_web':120,
        'web_size_type_ax_web':'ray_trace_median',
        'web_above_threshold_ax_web':True,
        'parent_width_maximum_thick_t':70,
        'min_child_width_max_thick_t':78,
        'child_skeletal_threshold_thick_t':3000,
        'child_skeletal_threshold_total_thick_t':10000,
        'child_angle_max_thick_t':40,
        'branch_skeletal_length_min_ax_double_b':2000,
        'total_downstream_skeleton_length_threshold_ax_double_b':2000,
        'upstream_skeletal_length_min_ax_double_b':5000,
        'axon_width_threshold_thin_ax_double_b':180,
        'axon_width_threshold_thick_ax_double_b':180,
        'downstream_width_max_fork_div':90,
        'upstream_width_max_fork_div':90,
        'total_downstream_skeleton_length_threshold_fork_div':4000,
        'individual_branch_length_threshold_fork_div':3000,
        'divergence_threshold_mean_fork_div':160,
        'comparison_distance_fork_div':400,
        'downstream_width_max_fork_min_dist':90,
        'upstream_width_max_fork_min_dist':145,
        'total_downstream_skeleton_length_threshold_fork_min_dist':4000,
        'individual_branch_length_threshold_fork_min_dist':4000,
        'min_distance_threshold_fork_min_dist':550,
        'upstream_width_threshold_ax_spine_at_inters':110,
        'downstream_width_threshold_ax_spine_at_inters':150,
        'child_skeletal_threshold_total_ax_spine_at_inters':10000,
        'upstream_width_threshold_min_syn_dist':110,
        'downstream_width_threshold_min_syn_dist':150,
        'min_synape_dist_min_syn_dist':1300,
        'branch_skeletal_length_min_double_b_axon_inh':2000,
        'total_downstream_skeleton_length_threshold_double_b_axon_inh':2000,
        'upstream_skeletal_length_min_double_b_axon_inh':5000,
        'axon_width_threshold_thin_double_b_axon_inh':180,
        'axon_width_threshold_thick_double_b_axon_inh':180,
        'attempt_upstream_pair_singular_double_b_axon_inh':True,
      },
    },
    'attributes':
    {
      'no_category':
      {
        #'default_graph_filters':[<function axon_webbing_filter at 0x7fbe0ffc2e50>, <function thick_t_filter at 0x7fbe0ffcf1f0>, <function axon_double_back_filter at 0x7fbe0ffcf160>, <function fork_divergence_filter at 0x7fbe0ffcf040>, <function fork_min_skeletal_distance_filter at 0x7fbe0ffcf0d0>, <function axon_spine_at_intersection_filter at 0x7fbe0ffc2ee0>, <function min_synapse_dist_to_branch_point_filter at 0x7fbe0ffc2f70>],
      },
    },
  },
  'motif_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
      },
    },
    'attributes':
    {
      'no_category':
      {
        #'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
  'neuron_geometry_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
      },
    },
    'attributes':
    {
      'no_category':
      {
        'voxel_to_nm_scaling':np.array([ 4,  4, 40]),
        #'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
  'neuron_statistics':
  {
    'global_parameters':
    {
      'no_category':
      {
      },
    },
    'attributes':
    {
      'no_category':
      {
        'voxel_to_nm_scaling':np.array([ 4,  4, 40]),
      },
    },
  },
  'neuron_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
        'skeletal_length_max_n_spines':3000,
      },
    },
    'attributes':
    {
      'no_category':
      {
        'data_voxel_adjustment':np.array([ 4,  4, 40]),
      },
    },
  },
  'preprocessing_vp2':
  {
    'global_parameters':
    {
      'axon_decomp':
      {
        'combine_close_skeleton_nodes_threshold_meshparty_axon':1300,
        'filter_end_node_length_meshparty_axon':1150,
        'filter_end_node_length_axon':1150,
        'invalidation_d_axon':1500,
        'smooth_neighborhood_axon':0,
        'meshparty_segment_size_axon':100,
        'stitch_floating_axon_pieces':True,
        'max_stitch_distance_high_fid_axon':5000,
        'floating_piece_face_threshold_high_fid_axon':50,
      },
      'decomp':
      {
        'width_threshold_MAP':500,
        'size_threshold_MAP':2000,
        'size_threshold_MAP_stitch':2000,
        'apply_expansion':False,
        'max_stitch_distance':8000,
        'max_stitch_distance_CGAL':5000,
        'filter_end_node_length':4000,
        'use_adaptive_invalidation_d':False,
        'use_adaptive_invalidation_d_floating':True,
        'axon_width_preprocess_limb_max':200,
        'limb_remove_mesh_interior_face_threshold':0,
        'surface_reconstruction_size':1000,
        'floating_piece_face_threshold':50,
        'invalidation_d':12000,
        'remove_mesh_interior_face_threshold':0,
      },
    },
    'attributes':
    {
      'no_category':
      {
      },
    },
  },
  'proofreading_utils':
  {
    'global_parameters':
    {
      'auto_proof':
      {
        'width_max_high_low_degree_inh':140,
        'upstream_width_max_high_low_degree_inh':180,
        'max_degree_to_resolve_absolute_low_degree_inh':5,
        'width_max_high_high_degree_inh_dendr':500,
        'upstream_width_max_high_high_degree_inh_dendr':500,
        'dendrite_branching_filters':False,
        'dendrite_branching_filters_inh':False,
        'double_back_threshold_inh_double_b':None,
      },
      'low_branch_clusters':
      {
        'max_skeletal_length_low_branch_clusters_dendrite':8000,
        'min_n_nodes_in_cluster_low_branch_clusters_dendrite':16,
        'max_skeletal_length_low_branch_clusters_axon':8000,
        'min_n_nodes_in_cluster_low_branch_clusters_axon':16,
        'skeletal_distance_from_soma_min_axon':10000,
      },
      'red_blue':
      {
        'n_red_points_red_blue':4,
      },
      'red_blue_multi_axon_on_dendrite':
      {
        'include_one_hop_downstream_error_branches_red_blue':True,
        'one_hop_downstream_error_branches_max_distance_red_blue':1000,
        'offset_distance_for_points_valid_red_blue':1700,
        'offset_distance_for_points_error_red_blue':1000,
        'n_points_red_blue':1,
        'n_red_points_red_blue':3,
        'n_blue_points_red_blue':2,
        'red_blue_points_method_red_blue':'closest_mesh_face',
        'pair_conn_comp_by_common_upstream_red_blue':True,
        'pair_conn_comp_errors_red_blue':True,
        'group_all_conn_comp_together_red_blue':False,
        'only_outermost_branches_red_blue':True,
        'min_error_downstream_length_total_red_blue':5000,
        'split_red_blue_by_common_upstream_red_blue':True,
        'use_undirected_graph_red_blue':False,
        'avoid_one_red_or_blue_red_blue':True,
        'min_cancel_distance_absolute_red_blue':1000,
      },
      'red_blue_multi_soma':
      {
        'include_one_hop_downstream_error_branches_red_blue':True,
        'one_hop_downstream_error_branches_max_distance_red_blue':4000,
        'offset_distance_for_points_valid_red_blue':3000,
        'offset_distance_for_points_error_red_blue':3000,
        'n_points_red_blue':1,
        'n_red_points_red_blue':3,
        'n_blue_points_red_blue':2,
        'red_blue_points_method_red_blue':'closest_mesh_face',
        'pair_conn_comp_by_common_upstream_red_blue':True,
        'pair_conn_comp_errors_red_blue':True,
        'group_all_conn_comp_together_red_blue':False,
        'only_outermost_branches_red_blue':True,
        'min_error_downstream_length_total_red_blue':5000,
        'split_red_blue_by_common_upstream_red_blue':True,
        'use_undirected_graph_red_blue':False,
        'avoid_one_red_or_blue_red_blue':True,
        'min_cancel_distance_absolute_red_blue':1000,
      },
      'split':
      {
        'remove_segment_threshold':1500,
        'remove_segment_threshold_round_2':2500,
        'consider_path_neighbors_for_removal':True,
        'offset_high_degree':2000,
        'comparison_distance_high_degree':2000,
        'match_threshold_high_degree':65,
        'skip_small_soma_connectors':True,
        'small_soma_connectors_skeletal_threshold':2500,
        'double_back_threshold':80,
        'offset_double_back':1000,
        'comparison_distance_double_back':6000,
        'width_jump_threshold':200,
        'simple_path_of_2_cut':False,
        'apply_double_back_first':True,
        'double_back_threshold_at_first':110,
        'min_skeletal_length_limb':15000,
      },
    },
    'attributes':
    {
      'no_category':
      {
        #'hdu':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
  'proximity_analysis_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
      },
    },
    'attributes':
    {
      'no_category':
      {
        'voxel_to_nm_scaling':np.array([ 4,  4, 40]),
        #'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
  'proximity_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
      },
    },
    'attributes':
    {
      'no_category':
      {
        'voxel_to_nm_scaling':np.array([ 4,  4, 40]),
        #'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
  'soma_extraction_utils':
  {
    'global_parameters':
    {
      'glia':
      {
        'glia_volume_threshold_in_um':2500,
        'glia_n_faces_threshold':400000,
        'glia_n_faces_min':100000,
      },
      'nuclei':
      {
        'nucleus_min':700,
        'nucleus_max':None,
      },
      'soma':
      {
        'outer_decimation_ratio':0.25,
        'large_mesh_threshold':20000,
        'large_mesh_threshold_inner':13000,
        'inner_decimation_ratio':0.25,
        'max_fail_loops':10,
        'remove_inside_pieces':True,
        'size_threshold_to_remove':1000,
        'pymeshfix_clean':False,
        'check_holes_before_pymeshfix':False,
        'second_poisson':False,
        'soma_width_threshold':0.32,
        'soma_size_threshold':9000,
        'soma_size_threshold_max':1200000,
        'volume_mulitplier':8,
        'side_length_ratio_threshold':6,
        'perform_pairing':False,
        'backtrack_soma_mesh_to_original':True,
        'backtrack_soma_size_threshold':8000,
        'poisson_backtrack_distance_threshold':None,
        'close_holes':False,
        'boundary_vertices_threshold':None,
        'last_size_threshold':2000,
        'segmentation_at_end':True,
        'largest_hole_threshold':17000,
        'second_pass_size_threshold':None,
      },
    },
    'attributes':
    {
      'no_category':
      {
      },
    },
  },
  'spine_utils':
  {
    'global_parameters':
    {
      'head_neck_shaft':
      {
        'head_smoothness':0.09,
        'head_ray_trace_min':240,
        'head_face_min':10,
        'only_allow_one_connected_component_neck':False,
      },
      'spine_identification':
      {
        'query':'median_mesh_center > 115 and n_faces_branch>100',
        'calculate_spine_volume':True,
        'clusters_threshold':5,
        'smoothness_threshold':0.08,
        'shaft_close_hole_area_top_2_mean_max':110000,
        'shaft_mesh_volume_max':300000000.0,
        'shaft_mesh_n_faces_min':10,
        'shaft_threshold':300,
        'spine_n_face_threshold_bare_min':6,
        'spine_sk_length_threshold_bare_min':306.6,
        'filter_by_volume_threshold_bare_min':900496.186,
        'bbox_oriented_side_max_min_bare_min':300,
        'spine_volume_to_spine_area_min_bare_min':0.008,
        'sdf_mean_min_bare_min':0,
        'spine_n_face_threshold':25,
        'spine_sk_length_threshold':1000,
        'filter_by_bounding_box_longest_side_length':True,
        'side_length_threshold':5000,
        'filter_out_border_spines':False,
        'skeleton_endpoint_nullification':True,
        'skeleton_endpoint_nullification_distance':2000,
        'soma_vertex_nullification':True,
        'border_percentage_threshold':0.3,
        'check_spine_border_perc':0.4,
        'filter_by_volume':True,
        'filter_by_volume_threshold':19835293,
      },
    },
    'attributes':
    {
      'no_category':
      {
      },
    },
  },
  'synapse_utils':
  {
    'global_parameters':
    {
      'no_category':
      {
      },
    },
    'attributes':
    {
      'no_category':
      {
        'voxel_to_nm_scaling':np.array([ 4,  4, 40]),
        #'hdju':<neurd.microns_volume_utils.DataInterface object at 0x7fbd2e4eceb0>,
      },
    },
  },
}

# %%
my_dict
# Out:
# {'apical_utils': {'global_parameters': {'apical': {'soma_angle_to_apical': 60,
#     'multi_apical_height': -460000,
#     'max_upward_angle_shaft_like': 30,
#     'min_upward_length_shaft_like': 3000,
#     'min_upward_per_match_shaft_like': 0.8,
#     'min_upward_length_backup_shaft_like': 20000,
#     'min_upward_per_match_backup_shaft_like': 0.5,
#     'width_min_shaft_like': 140,
#     'min_skeletal_length_filter_apical': 10000,
#     'min_distance_above_soma_filter_apical': 10000,
#     'candidate_connected_component_radius_apical': 5000,
#     'multi_apical_possible_apical': True,
#     'width_min_apical_high_soma': 450,
#     'distance_from_soma_apical_high_soma': 80000,
#     'min_thick_near_soma_skeletal_length_apical_high_soma': 10000,
#     'non_upward_skeletal_distance_upstream_buffer_filter_apical_one': -10000,
#     'soma_diff_buffer_filter_apical_one': -50000,
#     'downstream_vector_diff_buffer_filter_apical_one': -30000,
#     'default_tie_breaker_filter_apical_one': 'skeletal_length',
#     'add_low_degree_apicals_off_shaft_tuft': False,
#     'low_degree_apicals_min_angle_tuft': 0,
#     'low_degree_apicals_max_angle_tuft': 40},
#    'oblique': {'min_angle_oblique': 80,
#     'max_angle_oblique': 140,
#     'per_match_ref_vector_min_oblique': 0.8,
#     'dist_match_ref_vector_min_oblique': 10000}},
#   'attributes': {'no_category': {'rotation_function_axon_alignment': None,
#     'unrotation_function_axon_alignment': None}}},
#  'axon_utils': {'global_parameters': {'auto_proof': {'ray_trace_min_axon_spines': 270,
#     'ray_trace_max_axon_spines': 1200,
#     'skeletal_length_min_axon_spines': 1000,
#     'skeletal_length_max_axon_spines': 6000,
#     'n_synapses_pre_min_axon_spines': 1,
#     'n_synapses_pre_max_axon_spines': 3,
#     'n_faces_min_axon_spines': 90,
#     'downstream_upstream_dist_diff_axon_spines': 1000,
#     'downstream_dist_min_over_syn_axon_spines': 2000,
#     'exclude_starting_nodes_axon_spines': True,
#     'width_min_threshold_short_thick': 120,
#     'skeletal_length_max_threshold_short_thick': 3500,
#     'ray_trace_threshold_short_thick': 350,
#     'parent_width_threshold_short_thick': None,
#     'exclude_starting_nodes_short_thick': True,
#     'add_zero_width_segments_short_thick': True,
#     'width_min_threshold_parent_short_thick': 95,
#     'width_global_min_threshold_parent_short_thick': 40},
#    'axon_finding': {'axon_soma_angle_threshold_excitatory': 70,
#     'ais_max_distance_from_soma_excitatory': 14000,
#     'axon_classification_without_synapses_excitatory': False,
#     'axon_classification_without_synapses_if_no_candidate_excitatory': True,
#     'ais_max_distance_from_soma_inhibitory': 70000,
#     'axon_soma_angle_threshold': None,
#     'ais_syn_density_max': 0.00015,
#     'ais_syn_alternative_max': 2,
#     'ais_n_syn_pre_max': 1,
#     'ais_width_min': 95,
#     'ais_width_max': 650,
#     'max_search_distance': 80000,
#     'min_skeletal_length': 10000,
#     'n_postsyn_max': 15,
#     'postsyn_distance': 10000,
#     'ais_width_filter': True,
#     'ais_new_width_min': 140,
#     'ais_new_width_min_inhibitory': 140,
#     'ais_new_width_downstream_skeletal_length': 20000,
#     'ais_max_distance_from_soma': None,
#     'n_synapses_spine_offset_endpoint_upstream_max': 3,
#     'attempt_second_pass': True,
#     'ais_syn_density_max_backup': 0.0007,
#     'ais_n_syn_pre_max_backup': 100,
#     'max_search_distance_addition_backup': 0,
#     'return_best_candidate': True,
#     'best_candidate_method': 'max_skeletal_length_above_threshold_and_buffer',
#     'max_skeletal_length_min': 50000,
#     'max_skeletal_length_buffer': 20000,
#     'significant_lowest_density_min_skeletal_length': 15000,
#     'lowest_density_ratio': 4,
#     'downstream_distance_for_axon_angle': 30000,
#     'axon_classification_without_synapses_if_no_candidate': False,
#     'axon_classification_without_synapses': False,
#     'ais_syn_density_max_excitatory': None,
#     'ais_syn_density_max_backup_excitatory': None,
#     'candidate_downstream_postsyn_density_max': 0.00015},
#    'axon_on_dendrite': {'width_max_ax_on_dendr': 270,
#     'n_spines_max_ax_on_dendr': 10,
#     'n_synapses_post_spine_max_ax_on_dendr': 3,
#     'n_synapses_pre_min_ax_on_dendr': 1,
#     'synapse_pre_perc_min_ax_on_dendr': 0.6,
#     'synapse_pre_perc_downstream_min_ax_on_dendr': 0.9,
#     'axon_skeletal_legnth_min_ax_on_dendr': 2500,
#     'filter_away_thin_branches_ax_on_dendr': True,
#     'dendrite_width_min_ax_on_dendr': 80,
#     'thin_axon_skeletal_length_min_ax_on_dendr': 2500,
#     'thin_axon_n_synapses_post_downstream_max_ax_on_dendr': 3,
#     'mesh_area_min_ax_on_dendr': 1,
#     'closest_mesh_skeleton_dist_max_ax_on_dendr': 500,
#     'filter_away_myelination_myelin': True,
#     'min_skeletal_length_myelin': 5000,
#     'max_synapse_density_myelin': 7e-05,
#     'max_synapse_density_pass_2_myelin': 0.0001,
#     'min_skeletal_length_pass_2_myelin': 25000,
#     'min_distance_from_soma_pass_2_myelin': -1,
#     'max_width_myelin': 650,
#     'min_distance_from_soma_myelin': 10000,
#     'skeletal_length_downstream_min_ax_on_dendr': 7000,
#     'n_synapses_post_downstream_max_myelin': 5},
#    'bouton_webbing': {'max_bouton_width_to_check': 120,
#     'min_size_threshold_bouton': 27,
#     'max_size_threshold_bouton': 350,
#     'ray_trace_threshold_bouton': 200,
#     'split_significance_threshold_web': 20,
#     'maximum_volume_threshold_web': 3000,
#     'minimum_volume_threshold_web': 20},
#    'dendr_on_axon': {'min_distance_from_soma_inhibitory_dendr_on_axon': 10000,
#     'min_distance_from_soma_excitatory_dendr_on_axon': 10000,
#     'n_synapses_pre_min_dendr_on_axon': 1,
#     'synapse_post_perc_min_dendr_on_axon': 0.6,
#     'spine_density_min_dendr_on_axon': 0.00012,
#     'dendrite_width_min_dendr_on_axon': 170,
#     'dendrite_skeletal_length_min_dendr_on_axon': 3000,
#     'coarse_dendrite_filter': True,
#     'coarse_dendrite_axon_width_min': 300,
#     'coarse_dendrite_synapse_post_perc_min': 0.75,
#     'coarse_dendrite_n_synapses_post_min': 20,
#     'coarse_dendrite_n_spines_min': 10,
#     'coarse_dendrtie_spine_density': 0.00015,
#     'synapse_post_perc_downstream_min_dendr_on_axon': 0.9,
#     'n_synapses_pre_downstream_max_dendr_on_axon': 3,
#     'filter_away_spiney_branches_dendr_on_axon': False,
#     'n_synapses_post_spine_max_dendr_on_axon': 4,
#     'spine_density_max_dendr_on_axon': 0.00015}},
#   'attributes': {'no_category': {'rotation_function_axon_alignment': None,
#     'unrotation_function_axon_alignment': None,
#     'max_ais_distance_from_soma': 50000}}},
#  'branch_utils': {'global_parameters': {'no_category': {'offset_skeleton_vector': 500,
#     'comparison_distance_skeleton_vector': 3000}},
#   'attributes': {'no_category': {}}},
#  'cell_type_utils': {'global_parameters': {'no_category': {'lower_width_bound_spine': 140,
#     'upper_width_bound_spine': 520,
#     'apply_hand_made_low_rules': False,
#     'skeletal_length_processed_syn_min': 15000,
#     'skeletal_length_processed_spine_min': 15000,
#     'inhibitory_syn_density_shaft_min': 0.4,
#     'spine_threshold_syn_density': -1,
#     'skeletal_length_threshold_syn_density': 5000,
#     'upper_width_bound_syn_density': 10000}},
#   'attributes': {'no_category': {}}},
#  'classification_utils': {'global_parameters': {'axon': {'non_ais_width_axon': 200,
#     'ais_width_axon': 600,
#     'max_n_spines_axon': 7,
#     'max_spine_density_axon': 8e-05}},
#   'attributes': {'no_category': {}}},
#  'connectome_query_utils': {'global_parameters': {'no_category': {}},
#   'attributes': {'no_category': {}}},
#  'connectome_utils': {'global_parameters': {'no_category': {}},
#   'attributes': {'no_category': {}}},
#  'error_detection': {'global_parameters': {'auto_proof': {'double_back_threshold_axon_thick_inh': 135,
#     'double_back_threshold_axon_thin_inh': 140,
#     'min_upstream_skeletal_distance': 500,
#     'min_distance_from_soma_for_proof': 10000,
#     'min_degree_to_resolve': 3,
#     'max_degree_to_resolve_absolute': 1000,
#     'max_degree_to_resolve': 1000,
#     'max_degree_to_resolve_wide': 1000,
#     'max_degree_to_resolve_width_threshold': 200,
#     'width_min': 35,
#     'width_max': 170,
#     'upstream_width_max': None,
#     'axon_dependent': True,
#     'skip_distance_poly_x': (80, 200),
#     'skip_distance_poly_y': (1500, 2000),
#     'offset_high_d_match': 1000,
#     'comparison_distance_high_d_match': 2000,
#     'worst_case_sk_angle_match_threshold_high_d_match': 65,
#     'width_diff_max_high_d_match': 75,
#     'width_diff_perc_high_d_match': 0.6,
#     'perform_synapse_filter_high_d_match': True,
#     'synapse_density_diff_threshold_high_d_match': 0.00015,
#     'n_synapses_diff_threshold_high_d_match': 6,
#     'sk_angle_match_threshold_high_d_match': 45,
#     'sk_angle_buffer_high_d_match': 25,
#     'width_diff_perc_threshold_high_d_match': 0.15,
#     'width_diff_perc_buffer_high_d_match': 0.3,
#     'kiss_check_high_d_match': False,
#     'kiss_check_bbox_longest_side_threshold_high_d_match': 450,
#     'match_method_high_d_match': 'all_error_if_not_one_match',
#     'use_exclusive_partner_high_d_match': True,
#     'use_high_degree_false_positive_filter': True,
#     'width_min_high_degree_false_positive': 250,
#     'sibling_skeletal_angle_max_high_degree_false_positive': 110,
#     'skip_distance_low_d_match': 0,
#     'min_upstream_skeletal_distance_low_d_match': 2000,
#     'min_degree_to_resolve_low_d_match': 2,
#     'max_degree_to_resolve_wide_low_d_match': 3,
#     'max_degree_to_resolve_absolute_low_d_match': 1000,
#     'max_degree_to_resolve_low_d_match': 3,
#     'width_max_low_d_match': 170,
#     'upstream_width_max_low_d_match': None,
#     'offset_low_d_match': 1000,
#     'comparison_distance_low_d_match': 2000,
#     'worst_case_sk_angle_match_threshold_low_d_match': 65,
#     'width_diff_max_low_d_match': 75,
#     'width_diff_perc_low_d_match': 0.6,
#     'perform_synapse_filter_low_d_match': True,
#     'synapse_density_diff_threshold_low_d_match': 0.00015,
#     'n_synapses_diff_threshold_low_d_match': 6,
#     'width_max_dendr_restr': 500,
#     'width_max_dendr_double_back_restr': 500,
#     'upstream_skeletal_length_min_dendr_restr': 5000,
#     'upstream_skeletal_length_min_width_j_dendr': 5000,
#     'branch_skeletal_length_min_width_j_dendr': 7000,
#     'upstream_skeletal_length_min_for_min_width_j_dendr': 4000,
#     'width_jump_max_width_j_dendr': 200,
#     'upstream_skeletal_length_min_width_j_axon': 5000,
#     'branch_skeletal_length_min_width_j_axon': 8000,
#     'upstream_skeletal_length_min_for_min_width_j_axon': 4000,
#     'width_jump_max_width_j_axon': 55,
#     'axon_width_threshold_max_width_j_axon': 100,
#     'double_back_threshold_double_b_dendrite': 120,
#     'comparison_distance_double_b_dendrite': 3000,
#     'offset_double_b_dendrite': 0,
#     'branch_skeletal_length_min_double_b_dendrite': 7000},
#    'crossover': {'apply_width_filter': True,
#     'best_match_width_diff_max': 75,
#     'best_match_width_diff_max_perc': 0.6,
#     'best_match_width_diff_min': 0.25,
#     'no_non_cut_disconnected_comps': True,
#     'best_singular_match': True,
#     'lowest_angle_sum_for_pairs': False},
#    'high_degree_dendr': {'skip_distance_high_degree_dendr': 1200,
#     'width_max_high_degree_dendr': 300,
#     'upstream_width_max_high_degree_dendr': 300,
#     'offset_high_degree_dendr': 1500,
#     'comparison_distance_high_degree_dendr': 3000,
#     'width_diff_max_high_degree_dendr': 150,
#     'perform_synapse_filter_high_degree_dendr': False,
#     'width_diff_perc_threshold_high_d_match_dendr': 0.15,
#     'width_diff_perc_buffer_high_d_match_dendr': 0.2,
#     'use_high_degree_false_positive_filter_dendr': False,
#     'min_skeletal_length_endpoints_high_degree_dendr': 8000,
#     'min_distance_from_soma_mesh_high_degree_dendr': 7000}},
#   'attributes': {'no_category': {'double_back_threshold_axon_thick': 120,
#     'double_back_threshold_axon_thin': 127}}},
#  'graph_filters': {'global_parameters': {'no_category': {'child_width_maximum_ax_web_ax_web': 75,
#     'parent_width_maximum_ax_web': 75,
#     'child_skeletal_threshold_ax_web': 3000,
#     'child_skeletal_threshold_total_ax_web': 10000,
#     'child_angle_max_ax_web': 40,
#     'web_size_threshold_ax_web': 120,
#     'web_size_type_ax_web': 'ray_trace_median',
#     'web_above_threshold_ax_web': True,
#     'parent_width_maximum_thick_t': 70,
#     'min_child_width_max_thick_t': 78,
#     'child_skeletal_threshold_thick_t': 3000,
#     'child_skeletal_threshold_total_thick_t': 10000,
#     'child_angle_max_thick_t': 40,
#     'branch_skeletal_length_min_ax_double_b': 2000,
#     'total_downstream_skeleton_length_threshold_ax_double_b': 2000,
#     'upstream_skeletal_length_min_ax_double_b': 5000,
#     'axon_width_threshold_thin_ax_double_b': 180,
#     'axon_width_threshold_thick_ax_double_b': 180,
#     'downstream_width_max_fork_div': 90,
#     'upstream_width_max_fork_div': 90,
#     'total_downstream_skeleton_length_threshold_fork_div': 4000,
#     'individual_branch_length_threshold_fork_div': 3000,
#     'divergence_threshold_mean_fork_div': 160,
#     'comparison_distance_fork_div': 400,
#     'downstream_width_max_fork_min_dist': 90,
#     'upstream_width_max_fork_min_dist': 145,
#     'total_downstream_skeleton_length_threshold_fork_min_dist': 4000,
#     'individual_branch_length_threshold_fork_min_dist': 4000,
#     'min_distance_threshold_fork_min_dist': 550,
#     'upstream_width_threshold_ax_spine_at_inters': 110,
#     'downstream_width_threshold_ax_spine_at_inters': 150,
#     'child_skeletal_threshold_total_ax_spine_at_inters': 10000,
#     'upstream_width_threshold_min_syn_dist': 110,
#     'downstream_width_threshold_min_syn_dist': 150,
#     'min_synape_dist_min_syn_dist': 1300,
#     'branch_skeletal_length_min_double_b_axon_inh': 2000,
#     'total_downstream_skeleton_length_threshold_double_b_axon_inh': 2000,
#     'upstream_skeletal_length_min_double_b_axon_inh': 5000,
#     'axon_width_threshold_thin_double_b_axon_inh': 180,
#     'axon_width_threshold_thick_double_b_axon_inh': 180,
#     'attempt_upstream_pair_singular_double_b_axon_inh': True}},
#   'attributes': {'no_category': {}}},
#  'motif_utils': {'global_parameters': {'no_category': {}},
#   'attributes': {'no_category': {}}},
#  'neuron_geometry_utils': {'global_parameters': {'no_category': {}},
#   'attributes': {'no_category': {'voxel_to_nm_scaling': array([ 4,  4, 40])}}},
#  'neuron_statistics': {'global_parameters': {'no_category': {}},
#   'attributes': {'no_category': {'voxel_to_nm_scaling': array([ 4,  4, 40])}}},
#  'neuron_utils': {'global_parameters': {'no_category': {'skeletal_length_max_n_spines': 3000}},
#   'attributes': {'no_category': {'data_voxel_adjustment': array([ 4,  4, 40])}}},
#  'preprocessing_vp2': {'global_parameters': {'axon_decomp': {'combine_close_skeleton_nodes_threshold_meshparty_axon': 1300,
#     'filter_end_node_length_meshparty_axon': 1150,
#     'filter_end_node_length_axon': 1150,
#     'invalidation_d_axon': 1500,
#     'smooth_neighborhood_axon': 0,
#     'meshparty_segment_size_axon': 100,
#     'stitch_floating_axon_pieces': True,
#     'max_stitch_distance_high_fid_axon': 5000,
#     'floating_piece_face_threshold_high_fid_axon': 50},
#    'decomp': {'width_threshold_MAP': 500,
#     'size_threshold_MAP': 2000,
#     'size_threshold_MAP_stitch': 2000,
#     'apply_expansion': False,
#     'max_stitch_distance': 8000,
#     'max_stitch_distance_CGAL': 5000,
#     'filter_end_node_length': 4000,
#     'use_adaptive_invalidation_d': False,
#     'use_adaptive_invalidation_d_floating': True,
#     'axon_width_preprocess_limb_max': 200,
#     'limb_remove_mesh_interior_face_threshold': 0,
#     'surface_reconstruction_size': 1000,
#     'floating_piece_face_threshold': 50,
#     'invalidation_d': 12000,
#     'remove_mesh_interior_face_threshold': 0}},
#   'attributes': {'no_category': {}}},
#  'proofreading_utils': {'global_parameters': {'auto_proof': {'width_max_high_low_degree_inh': 140,
#     'upstream_width_max_high_low_degree_inh': 180,
#     'max_degree_to_resolve_absolute_low_degree_inh': 5,
#     'width_max_high_high_degree_inh_dendr': 500,
#     'upstream_width_max_high_high_degree_inh_dendr': 500,
#     'dendrite_branching_filters': False,
#     'dendrite_branching_filters_inh': False,
#     'double_back_threshold_inh_double_b': None},
#    'low_branch_clusters': {'max_skeletal_length_low_branch_clusters_dendrite': 8000,
#     'min_n_nodes_in_cluster_low_branch_clusters_dendrite': 16,
#     'max_skeletal_length_low_branch_clusters_axon': 8000,
#     'min_n_nodes_in_cluster_low_branch_clusters_axon': 16,
#     'skeletal_distance_from_soma_min_axon': 10000},
#    'red_blue': {'n_red_points_red_blue': 4},
#    'red_blue_multi_axon_on_dendrite': {'include_one_hop_downstream_error_branches_red_blue': True,
#     'one_hop_downstream_error_branches_max_distance_red_blue': 1000,
#     'offset_distance_for_points_valid_red_blue': 1700,
#     'offset_distance_for_points_error_red_blue': 1000,
#     'n_points_red_blue': 1,
#     'n_red_points_red_blue': 3,
#     'n_blue_points_red_blue': 2,
#     'red_blue_points_method_red_blue': 'closest_mesh_face',
#     'pair_conn_comp_by_common_upstream_red_blue': True,
#     'pair_conn_comp_errors_red_blue': True,
#     'group_all_conn_comp_together_red_blue': False,
#     'only_outermost_branches_red_blue': True,
#     'min_error_downstream_length_total_red_blue': 5000,
#     'split_red_blue_by_common_upstream_red_blue': True,
#     'use_undirected_graph_red_blue': False,
#     'avoid_one_red_or_blue_red_blue': True,
#     'min_cancel_distance_absolute_red_blue': 1000},
#    'red_blue_multi_soma': {'include_one_hop_downstream_error_branches_red_blue': True,
#     'one_hop_downstream_error_branches_max_distance_red_blue': 4000,
#     'offset_distance_for_points_valid_red_blue': 3000,
#     'offset_distance_for_points_error_red_blue': 3000,
#     'n_points_red_blue': 1,
#     'n_red_points_red_blue': 3,
#     'n_blue_points_red_blue': 2,
#     'red_blue_points_method_red_blue': 'closest_mesh_face',
#     'pair_conn_comp_by_common_upstream_red_blue': True,
#     'pair_conn_comp_errors_red_blue': True,
#     'group_all_conn_comp_together_red_blue': False,
#     'only_outermost_branches_red_blue': True,
#     'min_error_downstream_length_total_red_blue': 5000,
#     'split_red_blue_by_common_upstream_red_blue': True,
#     'use_undirected_graph_red_blue': False,
#     'avoid_one_red_or_blue_red_blue': True,
#     'min_cancel_distance_absolute_red_blue': 1000},
#    'split': {'remove_segment_threshold': 1500,
#     'remove_segment_threshold_round_2': 2500,
#     'consider_path_neighbors_for_removal': True,
#     'offset_high_degree': 2000,
#     'comparison_distance_high_degree': 2000,
#     'match_threshold_high_degree': 65,
#     'skip_small_soma_connectors': True,
#     'small_soma_connectors_skeletal_threshold': 2500,
#     'double_back_threshold': 80,
#     'offset_double_back': 1000,
#     'comparison_distance_double_back': 6000,
#     'width_jump_threshold': 200,
#     'simple_path_of_2_cut': False,
#     'apply_double_back_first': True,
#     'double_back_threshold_at_first': 110,
#     'min_skeletal_length_limb': 15000}},
#   'attributes': {'no_category': {}}},
#  'proximity_analysis_utils': {'global_parameters': {'no_category': {}},
#   'attributes': {'no_category': {'voxel_to_nm_scaling': array([ 4,  4, 40])}}},
#  'proximity_utils': {'global_parameters': {'no_category': {}},
#   'attributes': {'no_category': {'voxel_to_nm_scaling': array([ 4,  4, 40])}}},
#  'soma_extraction_utils': {'global_parameters': {'glia': {'glia_volume_threshold_in_um': 2500,
#     'glia_n_faces_threshold': 400000,
#     'glia_n_faces_min': 100000},
#    'nuclei': {'nucleus_min': 700, 'nucleus_max': None},
#    'soma': {'outer_decimation_ratio': 0.25,
#     'large_mesh_threshold': 20000,
#     'large_mesh_threshold_inner': 13000,
#     'inner_decimation_ratio': 0.25,
#     'max_fail_loops': 10,
#     'remove_inside_pieces': True,
#     'size_threshold_to_remove': 1000,
#     'pymeshfix_clean': False,
#     'check_holes_before_pymeshfix': False,
#     'second_poisson': False,
#     'soma_width_threshold': 0.32,
#     'soma_size_threshold': 9000,
#     'soma_size_threshold_max': 1200000,
#     'volume_mulitplier': 8,
#     'side_length_ratio_threshold': 6,
#     'perform_pairing': False,
#     'backtrack_soma_mesh_to_original': True,
#     'backtrack_soma_size_threshold': 8000,
#     'poisson_backtrack_distance_threshold': None,
#     'close_holes': False,
#     'boundary_vertices_threshold': None,
#     'last_size_threshold': 2000,
#     'segmentation_at_end': True,
#     'largest_hole_threshold': 17000,
#     'second_pass_size_threshold': None}},
#   'attributes': {'no_category': {}}},
#  'spine_utils': {'global_parameters': {'head_neck_shaft': {'head_smoothness': 0.09,
#     'head_ray_trace_min': 240,
#     'head_face_min': 10,
#     'only_allow_one_connected_component_neck': False},
#    'spine_identification': {'query': 'median_mesh_center > 115 and n_faces_branch>100',
#     'calculate_spine_volume': True,
#     'clusters_threshold': 5,
#     'smoothness_threshold': 0.08,
#     'shaft_close_hole_area_top_2_mean_max': 110000,
#     'shaft_mesh_volume_max': 300000000.0,
#     'shaft_mesh_n_faces_min': 10,
#     'shaft_threshold': 300,
#     'spine_n_face_threshold_bare_min': 6,
#     'spine_sk_length_threshold_bare_min': 306.6,
#     'filter_by_volume_threshold_bare_min': 900496.186,
#     'bbox_oriented_side_max_min_bare_min': 300,
#     'spine_volume_to_spine_area_min_bare_min': 0.008,
#     'sdf_mean_min_bare_min': 0,
#     'spine_n_face_threshold': 25,
#     'spine_sk_length_threshold': 1000,
#     'filter_by_bounding_box_longest_side_length': True,
#     'side_length_threshold': 5000,
#     'filter_out_border_spines': False,
#     'skeleton_endpoint_nullification': True,
#     'skeleton_endpoint_nullification_distance': 2000,
#     'soma_vertex_nullification': True,
#     'border_percentage_threshold': 0.3,
#     'check_spine_border_perc': 0.4,
#     'filter_by_volume': True,
#     'filter_by_volume_threshold': 19835293}},
#   'attributes': {'no_category': {}}},
#  'synapse_utils': {'global_parameters': {'no_category': {}},
#   'attributes': {'no_category': {'voxel_to_nm_scaling': array([ 4,  4, 40])}}}}

# %%
from neurd import synapse_utils as syu
paru.modes_global_param_and_attributes_dict_from_module(
    syu,
    verbose=True,
    clean_dict=False
)
# Out:
# mod_name = synapse_utils
# {'default': {'synapse_utils': {'global_parameters': {'no_category': {}},
#    'attributes': {'no_category': {'voxel_to_nm_scaling': array([ 4,  4, 40]),
#      'hdju': <neurd.microns_volume_utils.DataInterface at 0x7fbd2e4eceb0>}}}},
#  'h01': {'synapse_utils': {'global_parameters': {'no_category': {}},
#    'attributes': {'no_category': {'voxel_to_nm_scaling': array([ 8,  8, 33]),
#      'hdju': <neurd.h01_volume_utils.DataInterface at 0x7fbd2e4dbe80>}}}},
#  'microns': {'synapse_utils': {'global_parameters': {'no_category': {}},
#    'attributes': {'no_category': {}}}}}

# %%
from neurd import parameter_utils as paru
paru.paramater_list_from_module(
    apu,
    clean_dict=False
)
# Out:
# ['soma_angle_to_apical',
#  'multi_apical_height',
#  'max_upward_angle_shaft_like',
#  'min_upward_length_shaft_like',
#  'min_upward_per_match_shaft_like',
#  'min_upward_length_backup_shaft_like',
#  'min_upward_per_match_backup_shaft_like',
#  'width_min_shaft_like',
#  'min_skeletal_length_filter_apical',
#  'min_distance_above_soma_filter_apical',
#  'candidate_connected_component_radius_apical',
#  'multi_apical_possible_apical',
#  'width_min_apical_high_soma',
#  'distance_from_soma_apical_high_soma',
#  'min_thick_near_soma_skeletal_length_apical_high_soma',
#  'non_upward_skeletal_distance_upstream_buffer_filter_apical_one',
#  'soma_diff_buffer_filter_apical_one',
#  'downstream_vector_diff_buffer_filter_apical_one',
#  'default_tie_breaker_filter_apical_one',
#  'add_low_degree_apicals_off_shaft_tuft',
#  'low_degree_apicals_min_angle_tuft',
#  'low_degree_apicals_max_angle_tuft',
#  'min_angle_oblique',
#  'max_angle_oblique',
#  'per_match_ref_vector_min_oblique',
#  'dist_match_ref_vector_min_oblique',
#  'rotation_function_axon_alignment',
#  'unrotation_function_axon_alignment']

# %%
apu.rotation_function_axon_alignment

# %%
from neurd import apical_utils

# %% [markdown]
# # Setting the modules with the parameters

# %%
"""
Purpose: 

Things need for setting
-- parameters: for hard coded values
-- dynamic links: 
    hdju
    any functions
    
Pseudocode: 
"""
